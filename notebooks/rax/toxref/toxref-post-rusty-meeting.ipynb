# %%
import pandas as pd
import numpy as np
import pymongo
import sys
import os
from __future__ import print_function
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

TOP = '/'.join(os.getcwd().split('/')[:-3])+'/'
LIB = TOP+'lib'
if not LIB in sys.path: 
    sys.path.insert(0,LIB)

DAT_DIR = TOP + 'data/toxref/'
FIG_DIR = TOP + 'figs/toxref/'

from rax.genrapred import *

# %%
mongocon=pymongo.MongoClient("mongodb://ghelman:ghelman@pb.epa.gov/genra_dev_v4")
DB=mongocon['genra_dev_v4']
dsstox=DB['compound']
toxref=DB['toxrefdb2']

# %%
#Cyhalofop-butyl wrong units, now fixed in MySQL
record=list(toxref.find({'pods.pod_value':{'$gt':200000}},{'pods':1,'dsstox_sid':1,}))[0]
[pod for pod in record['pods'] if pod['pod_value']>300000 and pod['pod_type']=='loael']
# Out:
# [{u'casrn': u'122008-85-9',
#   u'chemical_id': 58743,
#   u'chemical_id_type': u'DSSTox_GSID',
#   u'direction': 1,
#   u'dose_level': 6,
#   u'dsstox_gsid': 34503,
#   u'dsstox_sid': u'DTXSID1034503',
#   u'effect_comment': None,
#   u'effect_desc': u'alkaline phosphatase (alp/alk)',
#   u'effect_desc_free': u'NA',
#   u'effect_id': 1971,
#   u'effect_profile_group_id': 29,
#   u'effect_profile_id': 2,
#   u'endpoint_category': u'systemic',
#   u'endpoint_id': 109,
#   u'endpoint_target': u'alkaline phosphatase (alp/alk)',
#   u'endpoint_type': u'clinical chemistry',
#   u'group_description': None,
#   u'group_id': 4,
#   u'group_name': u'systemic/clinical chemistry',
#   u'life_stage': u'adult',
#   u'max_dose_level': 6,
#   u'mg_kg_day_value': nan,
#   u'no_quant_data_reported': 0,
#   u'pod_id': 830561,
#   u'pod_tg_effect_id': 263069,
#   u'pod_type': u'loael',
#   u'pod_unit': u'mg/kg/day',
#   u'pod_value': 320000.0,
#   u'preferred_name': u'Cyhalofop-butyl',
# ...
