# %%
# %load ../env.py
# %load_ext autoreload
# %autoreload 2
# %pylab inline
# %matplotlib inline

import matplotlib.text as text
import pandas as pd
import numpy as np
import pylab as pl
import scipy as sp
import sys
import rpy2 
import os 

#Set environment variables


# Set up the local source files
TOP = '/'.join(os.getcwd().split('/')[:-2])+'/'
#TOP = "/share/home/ishah/ipynb/pb/HTTR_WF/"

LIB = TOP+'lib'
if not LIB in sys.path: 
    sys.path.insert(0,LIB)

os.environ['PYTHONPATH']=LIB


DAT_DIR = TOP + '/data/'
FIG_DIR = TOP + '/figs/'

if not os.path.exists(DAT_DIR): os.mkdir(DAT_DIR)
if not os.path.exists(FIG_DIR): os.mkdir(FIG_DIR)


from db.mongo import *

DB = openMongo(db='genra_dev_v4')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Test out searchFP

# %%
from db.fpsim import *

# %%
DB.chm_fp.find_one({'name':{'$regex':'conazole','$options':'i'}})
# Out:
# {u'_id': ObjectId('5a3abda59fb21e6ca8b83b4a'),
#  u'casrn': u'84625-61-6',
#  u'dsstox_cid': u'DTXCID903180',
#  u'dsstox_sid': u'DTXSID3023180',
#  u'httr': {u'ds': [u'httr_28',
#    u'httr_29',
#    u'httr_60',
#    u'httr_61',
#    u'httr_132',
#    u'httr_133',
#    u'httr_376',
#    u'httr_380',
#    u'httr_381',
#    u'httr_382',
#    u'httr_383',
#    u'httr_392',
#    u'httr_393',
#    u'httr_408',
#    u'httr_409',
#    u'httr_410',
#    u'httr_460',
#    u'httr_504',
#    u'httr_505',
#    u'httr_572',
#    u'httr_573',
#    u'httr_584',
#    u'httr_608',
#    u'httr_652',
#    u'httr_684',
#    u'httr_685',
#    u'httr_696',
#    u'httr_700',
#    u'httr_724',
#    u'httr_728',
#    u'httr_729',
#    u'httr_732',
#    u'httr_733',
#    u'httr_734',
#    u'httr_760',
#    u'httr_761',
#    u'httr_762',
#    u'httr_824',
#    u'httr_896',
#    u'httr_897',
#    u'httr_972',
#    u'httr_992',
#    u'httr_1044',
#    u'httr_1116',
#    u'httr_1180',
#    u'httr_1220',
#    u'httr_1228',
#    u'httr_1229',
#    u'httr_1232',
#    u'httr_1236',
#    u'httr_1312',
#    u'httr_1316',
#    u'httr_1356',
#    u'httr_1357',
#    u'httr_1428',
#    u'httr_1484',
#    u'httr_1488',
#    u'httr_1520',
#    u'httr_1532',
#    u'httr_1536',
#    u'httr_1580',
#    u'httr_1584',
#    u'httr_1596',
#    u'httr_1604',
#    u'httr_1608',
#    u'httr_1620',
#    u'httr_1621',
#    u'httr_1636',
#    u'httr_1644',
#    u'httr_1664',
#    u'httr_1668',
#    u'httr_1684',
#    u'httr_1685',
#    u'httr_1686',
#    u'httr_1687',
#    u'httr_1712',
#    u'httr_1808',
#    u'httr_1872',
#    u'httr_1873',
#    u'httr_1876',
#    u'httr_1877',
#    u'httr_1892',
#    u'httr_1893',
#    u'httr_1894',
#    u'httr_1908',
#    u'httr_1912',
#    u'httr_1924',
#    u'httr_1925',
#    u'httr_2016',
#    u'httr_2036',
#    u'httr_2040',
#    u'httr_2044'],
#   u'n': 92},
#  u'mrgn': {u'ds': [u'mrgn_1',
#    u'mrgn_33',
#    u'mrgn_37',
#    u'mrgn_42',
#    u'mrgn_43',
#    u'mrgn_70',
#    u'mrgn_72',
#    u'mrgn_80',
#    u'mrgn_84',
#    u'mrgn_88',
#    u'mrgn_102',
#    u'mrgn_107',
#    u'mrgn_110',
#    u'mrgn_151',
#    u'mrgn_165',
#    u'mrgn_208',
#    u'mrgn_216',
#    u'mrgn_233',
#    u'mrgn_249',
#    u'mrgn_263',
#    u'mrgn_283',
#    u'mrgn_294',
#    u'mrgn_314',
#    u'mrgn_322',
#    u'mrgn_324',
#    u'mrgn_328',
#    u'mrgn_337',
#    u'mrgn_366',
#    u'mrgn_378',
#    u'mrgn_407',
#    u'mrgn_489',
#    u'mrgn_496',
#    u'mrgn_534',
#    u'mrgn_548',
#    u'mrgn_561',
#    u'mrgn_564',
#    u'mrgn_629',
#    u'mrgn_645',
#    u'mrgn_650',
#    u'mrgn_651',
#    u'mrgn_656',
#    u'mrgn_661',
#    u'mrgn_672',
#    u'mrgn_683',
#    u'mrgn_687',
#    u'mrgn_695',
#    u'mrgn_718',
#    u'mrgn_747',
#    u'mrgn_749',
#    u'mrgn_762',
#    u'mrgn_771',
#    u'mrgn_816',
#    u'mrgn_837',
#    u'mrgn_875',
#    u'mrgn_926',
#    u'mrgn_932',
#    u'mrgn_935',
#    u'mrgn_944',
#    u'mrgn_1017',
#    u'mrgn_1019',
#    u'mrgn_1022',
#    u'mrgn_1024',
#    u'mrgn_1057',
#    u'mrgn_1060',
#    u'mrgn_1070',
#    u'mrgn_1100',
#    u'mrgn_1123',
#    u'mrgn_1136',
#    u'mrgn_1167',
#    u'mrgn_1209',
#    u'mrgn_1233',
#    u'mrgn_1255',
#    u'mrgn_1260',
#    u'mrgn_1343',
#    u'mrgn_1380',
#    u'mrgn_1391',
#    u'mrgn_1405',
#    u'mrgn_1414',
#    u'mrgn_1423',
#    u'mrgn_1452',
#    u'mrgn_1480',
#    u'mrgn_1508',
#    u'mrgn_1544',
#    u'mrgn_1591',
#    u'mrgn_1603',
#    u'mrgn_1642',
#    u'mrgn_1682',
#    u'mrgn_1683',
#    u'mrgn_1701',
#    u'mrgn_1750',
#    u'mrgn_1790',
#    u'mrgn_1825',
#    u'mrgn_1836',
#    u'mrgn_1838',
#    u'mrgn_1870',
#    u'mrgn_1873',
#    u'mrgn_1883',
#    u'mrgn_1923',
#    u'mrgn_1936',
#    u'mrgn_1943',
#    u'mrgn_1957',
#    u'mrgn_1969',
#    u'mrgn_1980',
#    u'mrgn_1986',
#    u'mrgn_2001',
#    u'mrgn_2027',
#    u'mrgn_2029',
#    u'mrgn_2037',
#    u'mrgn_2046'],
#   u'n': 109},
#  u'name': u'Itraconazole'}

# %%
DB.bio_fp.find_one()['dsstox_sid']
# Out:
# u'DTXSID6025486'

# %%
searchFP('DTXSID2020006',DB=DB,s0=0.2,fp='chm_mrgn')
# Out:
# [{u'casrn': u'103-90-2',
#   u'dsstox_sid': u'DTXSID2020006',
#   u'jaccard': 1.0,
#   u'name': u'Acetaminophen'},
#  {u'casrn': u'140-50-1',

#   u'jaccard': 0.42857142857142855,
#   u'name': u'Monoacetyldapsone hydroxylamine'},
#  {u'casrn': u'27375-52-6',
#   u'dsstox_sid': u'DTXSID4067305',
#   u'jaccard': 0.42857142857142855,
#   u'name': u'Acetamide, N-[4-[(2-hydroxyethyl)sulfonyl]phenyl]-'},
#  {u'casrn': u'29235-72-1',
#   u'dsstox_sid': u'DTXSID70183490',
#   u'jaccard': 0.4222222222222222,
#   u'name': u'Propanamide, 3-(diethylamino)-N-(4-hydroxyphenyl)-, monohydrochloride'},
#  {u'casrn': u'37519-14-5',
#   u'dsstox_sid': u'DTXSID50190960',
#   u'jaccard': 0.42105263157894735,
#   u'name': u'3-Hydroxyacetaminophen'},
#  {u'casrn': u'1752-24-5',
#   u'dsstox_sid': u'DTXSID6061945',
#   u'jaccard': 0.41935483870967744,
#   u'name': u"Phenol, 4,4'-iminobis-"},
#  {u'casrn': u'36141-82-9',
#   u'dsstox_sid': u'DTXSID5046229',
#   u'jaccard': 0.4186046511627907,
#   u'name': u'Diamfenetide'},
#  {u'casrn': u'20330-52-3',
#   u'dsstox_sid': u'DTXSID40174239',
#   u'jaccard': 0.4186046511627907,
#   u'name': u'p-Pentylacetanilide'},
#  {u'casrn': u'28533-02-0',
#   u'dsstox_sid': u'DTXSID20182756',
#   u'jaccard': 0.4186046511627907,
#   u'name': u"4-Nitro-4'-(acetylamino)biphenyl"}]

# %%
searchFP('DTXSID6025486',DB=DB,s0=0.2,fp='bio_txct')
# Out:
# [{u'casrn': u'51-30-9',
#   u'dsstox_sid': u'DTXSID6025486',
#   u'jaccard': 1.0,
#   u'name': u'Isoproterenol hydrochloride'},
#  {u'casrn': u'126-11-4',
#   u'dsstox_sid': u'DTXSID8027034',
#   u'jaccard': 0.2318840579710145,
#   u'name': u'2-(Hydroxymethyl)-2-nitro-1,3-propanediol'},
#  {u'casrn': u'2243-62-1',
#   u'dsstox_sid': u'DTXSID3020916',
#   u'jaccard': 0.22935779816513763,
#   u'name': u'1,5-Naphthalenediamine'},
#  {u'casrn': u'1111-78-0',
#   u'dsstox_sid': u'DTXSID9027360',
#   u'jaccard': 0.22580645161290322,
#   u'name': u'Ammonium carbamate'},
#  {u'casrn': u'375-85-9',
#   u'dsstox_sid': u'DTXSID1037303',
#   u'jaccard': 0.2054794520547945,
#   u'name': u'Perfluoroheptanoic acid'},
#  {u'casrn': u'67-20-9',
#   u'dsstox_sid': u'DTXSID7020972',
#   u'jaccard': 0.20408163265306123,
#   u'name': u'Nitrofurantoin'},
#  {u'casrn': u'3252-43-5',
#   u'dsstox_sid': u'DTXSID3024940',
#   u'jaccard': 0.203125,
#   u'name': u'Dibromoacetonitrile'}]

# %%
DB.tox1_fp.find_one()
# Out:
# {u'_id': ObjectId('56d9da9814fd09250ac2fe7f'),
#  u'casrn': u'103-90-2',
#  u'dsstox_cid': u'DTXCID606',
#  u'name': u'Acetaminophen',
#  u'tox1': {u'ds': [u'SUB:liver',
#    u'SUB:lymph_node',
#    u'MGR:offspring_survival-early',
#    u'SUB:uterus',
#    u'SUB:body_weight',
#    u'CHR:thyroid_gland',
#    u'MGR:pituitary_gland',
#    u'SUB:mortality',
#    u'MGR:liver',
#    u'MGR:reproductive_performance',
#    u'SUB:testes',
#    u'MGR:body_weight',
#    u'SAC:body_weight',
#    u'SUB:ovary',
#    u'CHR:tissue_nos',
#    u'CHR:kidney',
#    u'SUB:thymus',
#    u'MGR:brain',
#    u'CHR:body_weight',
#    u'MGR:sperm_morphology',
#    u'SAC:food_consumption',
#    u'SUB:kidney',
#    u'SUB:food_consumption',
#    u'SUB:clinical_signs',
#    u'CHR:parathyroid_gland'],
#   u'n': 25},
#  u'toxq1': {u'CHR:[not_in_list]': 0.0,
#   u'CHR:abdominal_cavity': 0.0,
#   u'CHR:adrenal_gland': 0.0,
#   u'CHR:artery_(general)': 0.0,
#   u'CHR:auditory_startle_reflex_habituation': 0.0,
#   u'CHR:bile_duct': 0.0,
#   u'CHR:blood': 0.0,
#   u'CHR:blood_vessel': 0.0,
#   u'CHR:body_weight': 90.0,
#   u'CHR:bone': 0.0,
#   u'CHR:bone_marrow': 0.0,
#   u'CHR:brain': 0.0,
#   u'CHR:bronchus': 0.0,
#   u'CHR:cervix': 0.0,
#   u'CHR:clinical_chemistry': 0.0,
#   u'CHR:clinical_signs': 0.0,
#   u'CHR:clitoral_gland': 0.0,
#   u'CHR:coagulating_gland': 0.0,
#   u'CHR:ear': 0.0,
#   u'CHR:epididymis': 0.0,
#   u'CHR:esophagus': 0.0,
#   u'CHR:estrous_cycle': 0.0,
#   u'CHR:eye': 0.0,
#   u'CHR:food_consumption': 0.0,
#   u'CHR:gallbladder': 0.0,
#   u'CHR:general': 0.0,
#   u'CHR:harderian_gland': 0.0,
#   u'CHR:heart': 0.0,
#   u'CHR:hematology': 0.0,
#   u'CHR:intestine_large': 0.0,
#   u'CHR:intestine_small': 0.0,
#   u'CHR:kidney': 30.0,
#   u'CHR:lacrimal_gland': 0.0,
#   u'CHR:larynx': 0.0,
#   u'CHR:liver': 0.0,
#   u'CHR:locomotion': 0.0,
#   u'CHR:lung': 0.0,
#   u'CHR:lymph_node': 0.0,
#   u'CHR:mammary_gland': 0.0,
#   u'CHR:mesentery': 0.0,
#   u'CHR:mortality': 0.0,
#   u'CHR:motor_activity': 0.0,
#   u'CHR:nerve': 0.0,
#   u'CHR:nose': 0.0,
#   u'CHR:oral_mucosa': 0.0,
#   u'CHR:other': 0.0,
#   u'CHR:ovary': 0.0,
#   u'CHR:pancreas': 0.0,
#   u'CHR:parathyroid': 0.0,
#   u'CHR:parathyroid_gland': 30.0,
#   u'CHR:penis': 0.0,
#   u'CHR:peritoneum': 0.0,
#   u'CHR:pharynx': 0.0,
#   u'CHR:pituitary_gland': 0.0,
#   u'CHR:pleura': 0.0,
#   u'CHR:preputial_gland': 0.0,
#   u'CHR:prostate': 0.0,
#   u'CHR:reflexes': 0.0,
#   u'CHR:salivary_glands': 0.0,
#   u'CHR:seminal_vesicle': 0.0,
#   u'CHR:skeletal_muscle': 0.0,
#   u'CHR:skin': 0.0,
#   u'CHR:sperm_measure': 0.0,
#   u'CHR:sperm_morphology': 0.0,
#   u'CHR:spinal_cord': 0.0,
#   u'CHR:spleen': 0.0,
#   u'CHR:stomach': 0.0,
#   u'CHR:testes': 0.0,
#   u'CHR:thymus': 0.0,
#   u'CHR:thyroid_gland': 90.0,
#   u'CHR:tissue_nos': 35.0,
#   u'CHR:tongue': 0.0,
#   u'CHR:tooth': 0.0,
#   u'CHR:trachea': 0.0,
#   u'CHR:uncertain_primary_site': 0.0,
#   u'CHR:ureter': 0.0,
#   u'CHR:urethra': 0.0,
#   u'CHR:urinalysis': 0.0,
#   u'CHR:urinary_bladder': 0.0,
#   u'CHR:uterus': 0.0,
#   u'CHR:vagina': 0.0,
#   u'CHR:water_consumption': 0.0,
#   u"CHR:zymbal's_gland": 0.0,
#   u'MGR:[clinical]': 0.0,
#   u'MGR:[not_in_list]': 0.0,
#   u'MGR:adrenal_gland': 0.0,
#   u'MGR:age_landmark': 0.0,
#   u'MGR:auditory_startle_reflex_habituation': 0.0,
#   u'MGR:blood': 0.0,
#   u'MGR:body_weight': 357.0,
#   u'MGR:bone': 0.0,
#   u'MGR:bone_marrow': 0.0,
#   u'MGR:brain': 1430.0,
#   u'MGR:cervix': 0.0,
#   u'MGR:clinical_chemistry': 0.0,
#   u'MGR:clinical_signs': 0.0,
#   u'MGR:coagulating_gland': 0.0,
#   u'MGR:coordination': 0.0,
#   u'MGR:developmental_landmark': 0.0,
#   u'MGR:diaphragm': 0.0,
#   u'MGR:ear': 0.0,
#   u'MGR:epididymis': 0.0,
#   u'MGR:esophagus': 0.0,
#   u'MGR:estrous_cycle': 0.0,
#   u'MGR:estrous_cycle_length': 0.0,
#   u'MGR:eye': 0.0,
#   u'MGR:food_consumption': 0.0,
#   u'MGR:general': 0.0,
#   u'MGR:gonad': 0.0,
#   u'MGR:hair_growth': 0.0,
#   u'MGR:heart': 0.0,
#   u'MGR:hematology': 0.0,
#   u'MGR:intestine_large': 0.0,
#   u'MGR:intestine_small': 0.0,
#   u'MGR:kidney': 0.0,
#   u'MGR:limb': 0.0,
#   u'MGR:liver': 1430.0,
#   u'MGR:locomotion': 0.0,
#   u'MGR:lung': 0.0,
#   u'MGR:lymph_node': 0.0,
#   u'MGR:mammary_gland': 0.0,
#   u'MGR:maternal_wastage': 0.0,
#   u'MGR:maze': 0.0,
#   u'MGR:mortality': 0.0,
#   u'MGR:motor_activity': 0.0,
#   u'MGR:mouth_/_jaw': 0.0,
#   u'MGR:nerve': 0.0,
#   u'MGR:nose': 0.0,
#   u'MGR:offspring_survival-early': 1430.0,
#   u'MGR:offspring_survival-late': 0.0,
#   u'MGR:other': 0.0,
#   u'MGR:ovary': 0.0,
#   u'MGR:pancreas': 0.0,
#   u'MGR:parathyroid': 0.0,
#   u'MGR:parathyroid_gland': 0.0,
#   u'MGR:paw_/_digit': 0.0,
#   u'MGR:penis': 0.0,
#   u'MGR:pituitary_gland': 1430.0,
#   u'MGR:placenta': 0.0,
#   u'MGR:prostate': 0.0,
#   u'MGR:reflexes': 0.0,
#   u'MGR:reproductive_outcome': 0.0,
#   u'MGR:reproductive_performance': 1430.0,
#   u'MGR:salivary_glands': 0.0,
#   u'MGR:seminal_vesicle': 0.0,
#   u'MGR:sexual_developmental_landmark': 0.0,
#   u'MGR:skeletal_muscle': 0.0,
#   u'MGR:skin': 0.0,
#   u'MGR:sperm_measure': 0.0,
#   u'MGR:sperm_morphology': 1430.0,
#   u'MGR:spinal_cord': 0.0,
#   u'MGR:spleen': 0.0,
#   u'MGR:stomach': 0.0,
#   u'MGR:testes': 0.0,
#   u'MGR:thymus': 0.0,
#   u'MGR:thyroid_gland': 0.0,
#   u'MGR:tissue_nos': 0.0,
#   u'MGR:tooth': 0.0,
#   u'MGR:trunk': 0.0,
#   u'MGR:ureter': 0.0,
#   u'MGR:urinalysis': 0.0,
#   u'MGR:urinary_bladder': 0.0,
#   u'MGR:uterus': 0.0,
#   u'MGR:vagina': 0.0,
#   u'MGR:water_consumption': 0.0,
#   u'SAC:[not_in_list]': 0.0,
#   u'SAC:abdominal_cavity': 0.0,
#   u'SAC:adrenal_gland': 0.0,
#   u'SAC:blood': 0.0,
#   u'SAC:blood_vessel': 0.0,
#   u'SAC:body_weight': 625.0,
#   u'SAC:bone': 0.0,
#   u'SAC:bone_marrow': 0.0,
#   u'SAC:brain': 0.0,
#   u'SAC:clinical_chemistry': 0.0,
#   u'SAC:clinical_signs': 0.0,
#   u'SAC:epididymis': 0.0,
#   u'SAC:esophagus': 0.0,
#   u'SAC:estrous_cycle': 0.0,
#   u'SAC:eye': 0.0,
#   u'SAC:food_consumption': 625.0,
#   u'SAC:gallbladder': 0.0,
#   u'SAC:general': 0.0,
#   u'SAC:heart': 0.0,
#   u'SAC:hematology': 0.0,
#   u'SAC:intestine_large': 0.0,
#   u'SAC:intestine_small': 0.0,
#   u'SAC:kidney': 0.0,
#   u'SAC:larynx': 0.0,
#   u'SAC:liver': 0.0,
#   u'SAC:lung': 0.0,
#   u'SAC:lymph_node': 0.0,
#   u'SAC:mammary_gland': 0.0,
#   u'SAC:mesentery': 0.0,
#   u'SAC:mortality': 0.0,
#   u'SAC:nerve': 0.0,
#   u'SAC:nose': 0.0,
#   u'SAC:offspring_survival-early': 0.0,
#   u'SAC:oral_mucosa': 0.0,
#   u'SAC:other': 0.0,
#   u'SAC:ovary': 0.0,
#   u'SAC:pancreas': 0.0,
#   u'SAC:penis': 0.0,
#   u'SAC:peritoneum': 0.0,
#   u'SAC:pituitary_gland': 0.0,
#   u'SAC:prostate': 0.0,
#   u'SAC:reproductive_performance': 0.0,
#   u'SAC:salivary_glands': 0.0,
#   u'SAC:seminal_vesicle': 0.0,
#   u'SAC:skeletal_muscle': 0.0,
#   u'SAC:skin': 0.0,
#   u'SAC:sperm_measure': 0.0,
#   u'SAC:sperm_morphology': 0.0,
#   u'SAC:spinal_cord': 0.0,
#   u'SAC:spleen': 0.0,
#   u'SAC:stomach': 0.0,
#   u'SAC:testes': 0.0,
#   u'SAC:thoracic_cavity': 0.0,
#   u'SAC:thymus': 0.0,
#   u'SAC:thyroid_gland': 0.0,
#   u'SUB:thoracic_cavity': 0.0,
#   u'SUB:thymus': 1250.0,
#   u'SUB:thyroid_gland': 0.0,
#   u'SUB:tissue_nos': 0.0,
#   u'SUB:tongue': 0.0,
#   u'SUB:tooth': 0.0,
#   u'SUB:trachea': 0.0,
#   u'SUB:uncertain_primary_site': 0.0,
#   u'SUB:ureter': 0.0,
#   u'SUB:urethra': 0.0,
#   u'SUB:urinalysis': 0.0,
#   u'SUB:urinary_bladder': 0.0,
#   u'SUB:uterus': 1250.0,
#   u'SUB:vagina': 0.0,
#   u'SUB:water_consumption': 0.0}}

# %%
searchFP('DTXSID2020006',DB=DB,s0=0.1,fp='toxp_txrf',sel_by='toxp_txrf')

# %% [markdown]
# ## Test out getfp

# %%
from db.getfp import *

# %%
X = getFP(['DTXSID2020006'],fp='toxp_txrf',DB=DB,fill=0)
X
# Out:
# fp             CHR:Body Weight  CHR:Kidney  CHR:Parathyroid Gland  \
# dsstox_sid
# DTXSID2020006                1           1                      1
#
# fp             CHR:Thyroid Gland  CHR:Tissue NOS  MGR:Body Weight  MGR:Brain  \
# dsstox_sid
# DTXSID2020006                  1               1                1          1
#
# fp             MGR:Liver  MGR:Offspring Survival-Early  MGR:Pituitary Gland  \
# dsstox_sid
# DTXSID2020006          1                             1                    1
#
# fp                ...      SUB:Clinical Signs  SUB:Food Consumption  \
# dsstox_sid        ...
# DTXSID2020006     ...                       1                     1
#
# fp             SUB:Kidney  SUB:Liver  SUB:Lymph Node  SUB:Mortality  \
# dsstox_sid
# DTXSID2020006           1          1               1              1
#
# fp             SUB:Ovary  SUB:Testes  SUB:Thymus  SUB:Uterus
# dsstox_sid
# DTXSID2020006          1           1           1           1
#
# [1 rows x 25 columns]

# %%
X = getFP(['DTXSID2020006'],fp='toxn_txrf',DB=DB,fill=0)
X
# Out:
# fp             CHR:Abdominal Cavity  CHR:Adrenal Gland  CHR:Artery (General)  \
# dsstox_sid
# DTXSID2020006                     1                  1                     1
#
# fp             CHR:Auditory Startle Reflex Habituation  CHR:Bile duct  \
# dsstox_sid
# DTXSID2020006                                        1              1
#
# fp             CHR:Blood  CHR:Blood vessel  CHR:Bone  CHR:Bone Marrow  \
# dsstox_sid
# DTXSID2020006          1                 1         1                1
#
# fp             CHR:Brain        ...          SUB:Tooth  SUB:Trachea  \
# dsstox_sid                      ...
# DTXSID2020006          1        ...                  1            1
#
# fp             SUB:Uncertain Primary Site  SUB:Ureter  SUB:Urethra  \
# dsstox_sid
# DTXSID2020006                           1           1            1
#
# fp             SUB:Urinalysis  SUB:Urinary Bladder  SUB:Vagina  \
# dsstox_sid
# DTXSID2020006               1                    1           1
#
# fp             SUB:Water Consumption  SUB:[Not In List]
# dsstox_sid
# DTXSID2020006                      1                  1
#
# [1 rows x 288 columns]

# %%
from db.fpsim import *

# %%
from rax.genrapred import *

# %%
help(runGenRA)
# Out:
# Help on function runGenRA in module rax.genrapred:
#
# runGenRA(cid, Y=None, CID=None, DB=None, fp_x='chm_mrgn', fp_y='toxp_txrf', sel_by=None, k0=10, s0=0.1, metric='jaccard', pred=True, ret=None, wt=True, n_perm=100)
#     cid  : the DSSTOX CID of the target chemical (required)
#
#     Y    : list of toxicities for evaluation of activities (optional)
#
#     CID  : list of dsstox_cids of chemicals to consider in neighbourhood (optional)
#
#     DB   : reference to mongodb (required)
#
#     fp_x : fingerprint for chemical similarity. Options:
#           - chm_mrgn: RDKit Morgan (default)
#           - chm_httr: RDKit Torsion
#           - chm_ct  : ChemoTypes
#
#     fp_y: fingerprint for predicted bioactivity. This is resolved to a specific
#           database collection and attribute. Currently only consider toxicity. Options
#           - toxp_txrf: toxref toxicity classifications.
#
#     sel_by: when finding nearest neighbours of target, select the neighbours based on
#             availability of this information. Options:
#           - tox_txrf: toxref toxicity classifications.
#
#     k0    : Number of nearest neighbours to consider
#
#     s0    : Similarity threshold measured by metric
#
#     metric: Similarity metric. Options:
#           - Jaccard (default)
#
#     n_perm: Number of permutations for testing significance of AUC
#
#     pred  : Whether to predict activity for target or just calculate the
#             predictive performances
#
#     ret   : Results to return. Options:
#           - full: a list with three elements
#             1. Predictions for target
#             2. Performance results for neighbourhood
#             3. Similarity scores for chemicals in neighbourhood
#           - else:
#             * Performance results
#
#     Description of returned values:
#
#     * Predictions for target - a list of predictions, one for each bioactivity outcome.
#       Each prediction is a dict with the following keys:
#       - dsstox_cid  : DSSTOX CID of target
#       - out         : bioactivity/toxicity endpoint
#       - k0          : k0
#       - s0          : s0
#       - fp          : fp_x
#       - a_t         : Observed activity of target for out
#       - a_s         : Similarity weighted bioactivity of target across neighbours
#       - a_p         : Predicted activity 0/1 based on threshold t0
#       - auc         : ROC area under curve across a_s and a_t for neighbours
#       - t0          : activity threshold that produces best balanced accuracy
#       - p_val       : the significance of auc across n_perm
#       - pred        : the prediction class
#                       if a_t known  : one of TN/TP/FN/FP
#                       if a_t unknown: one of Pos/Neg
#
#     * Performance results for neighbourhood as a dict in which keys are
#       bioactivity/toxicity endpoints and values are dictionaries with the following
#       keys:
#       - out        : Binary activity of each analog (no effect:0/effect: 1)
#       - act        : Similarity weighted activities for each analog in the
#                      neighbourhood as a pandas.DataFrame with the following columns:
#              - dsstox_cid: DSSTOX CID of analog (index)
#              - a_t       : True activity of analog
#              - a_p       : Simiarity weighted bioactivity of analog
#              - n_p       : Number of positives
#              - n_n       : Number of negatives
#       - roc        : The receiver operating characteristic for the neighbourhood
#                      as a dataframe with the following columns:
#              - fpr       : false positive rate
#              - sp        : specificity
#              - sn        : sensitivity
#              - t0        : score threshold
#              - BA        : balanced accuracy = 0.5 * (sn+sp)
#
#     * Similarity matrix for all k0 chemicals considered in neighbourhood as a
#       k0xk0 pandas.DataFrame in which rows and columns are indexed by dsstox_cid and
#       the value of each cell is the similarity score based on above metric

# %%
SID = [i['dsstox_sid'] for i in searchFP('DTXSID2020006',DB=DB,s0=0.01,fp='chm_mrgn')]
DB.tox_fp.find({'dsstox_sid':{'$in':SID}}).count()
# Out:
# 1

# %%
runGenRA('DTXSID3023180',DB=DB,s0=0.01,k0=10,dbg=True)
# Out:
# There are 10 hits
# The FP has shape (10, 183)
# []
