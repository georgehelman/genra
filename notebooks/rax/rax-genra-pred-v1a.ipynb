# %%
# %load ../env.py
# %load_ext autoreload
# %autoreload 2
# %pylab inline
# %matplotlib inline

import matplotlib.text as text
import pandas as pd
import numpy as np
import pylab as pl
import scipy as sp
import sys
import rpy2 
import os 

#Set environment variables


# Set up the local source files
TOP = '/'.join(os.getcwd().split('/')[:-2])+'/'
#TOP = "/share/home/ishah/ipynb/pb/HTTR_WF/"

LIB = TOP+'lib'
if not LIB in sys.path: 
    sys.path.insert(0,LIB)

os.environ['PYTHONPATH']=LIB


DAT_DIR = TOP + '/data/'
FIG_DIR = TOP + '/figs/'

if not os.path.exists(DAT_DIR): os.mkdir(DAT_DIR)
if not os.path.exists(FIG_DIR): os.mkdir(FIG_DIR)


from db.mongo import *

DB = openMongo(db='genra_dev_v4')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Test out searchFP

# %%
DB.chm_fp.find_one({'name':{'$regex':'conazole','$options':'i'}})
# Out:
# {u'_id': ObjectId('5a3afbde072e6004424e7cfb'),
#  u'casrn': u'83657-19-6',
#  u'dsstox_cid': u'DTXCID10196463',
#  u'dsstox_sid': u'DTXSID50273969',
#  u'httr': {u'ds': [u'httr_216',
#    u'httr_217',
#    u'httr_376',
#    u'httr_380',
#    u'httr_381',
#    u'httr_460',
#    u'httr_461',
#    u'httr_480',
#    u'httr_481',
#    u'httr_552',
#    u'httr_596',
#    u'httr_652',
#    u'httr_653',
#    u'httr_684',
#    u'httr_752',
#    u'httr_1220',
#    u'httr_1232',
#    u'httr_1236',
#    u'httr_1292',
#    u'httr_1396',
#    u'httr_1404',
#    u'httr_1484',
#    u'httr_1532',
#    u'httr_1533',
#    u'httr_1620',
#    u'httr_1621',
#    u'httr_1664',
#    u'httr_1712',
#    u'httr_1713',
#    u'httr_1744',
#    u'httr_1844',
#    u'httr_1872',
#    u'httr_1892',
#    u'httr_2036',
#    u'httr_2040'],
#   u'n': 35},
#  u'mrgn': {u'ds': [u'mrgn_1',
#    u'mrgn_43',
#    u'mrgn_61',
#    u'mrgn_65',
#    u'mrgn_114',
#    u'mrgn_165',
#    u'mrgn_200',
#    u'mrgn_216',
#    u'mrgn_227',
#    u'mrgn_234',
#    u'mrgn_366',
#    u'mrgn_378',
#    u'mrgn_392',
#    u'mrgn_489',
#    u'mrgn_548',
#    u'mrgn_561',
#    u'mrgn_626',
#    u'mrgn_651',
#    u'mrgn_694',
#    u'mrgn_789',
#    u'mrgn_796',
#    u'mrgn_807',
#    u'mrgn_816',
#    u'mrgn_875',
#    u'mrgn_891',
#    u'mrgn_932',
#    u'mrgn_935',
#    u'mrgn_961',
#    u'mrgn_1007',
#    u'mrgn_1057',
#    u'mrgn_1086',
#    u'mrgn_1097',
#    u'mrgn_1147',
#    u'mrgn_1183',
#    u'mrgn_1209',
#    u'mrgn_1251',
#    u'mrgn_1306',
#    u'mrgn_1380',
#    u'mrgn_1398',
#    u'mrgn_1480',
#    u'mrgn_1603',
#    u'mrgn_1683',
#    u'mrgn_1746',
#    u'mrgn_1750',
#    u'mrgn_1753',
#    u'mrgn_1767',
#    u'mrgn_1773',
#    u'mrgn_1781',
#    u'mrgn_1839',
#    u'mrgn_1873',
#    u'mrgn_1986',
#    u'mrgn_2009'],
#   u'n': 52},
#  u'name': u'(S)-Diniconazole'}

# %%
DB.bio_fp.find_one()['dsstox_sid']
# Out:
# u'DTXSID6025486'

# %%
searchFP('DTXSID2020006',DB=DB,s0=0.5,fp='chm_mrgn')
# Out:
# [{u'casrn': u'103-90-2',
#   u'dsstox_sid': u'DTXSID2020006',
#   u'jaccard': 1.0,
#   u'name': u'Acetaminophen'},
#  {u'casrn': u'65783-82-6',
#   u'dsstox_sid': u'DTXSID80676747',
#   u'jaccard': 0.9615384615384616,
#   u'name': u'N-(4-Hydroxyphenyl)acetamide--hydrogen chloride (1/1)'},
#  {u'casrn': u'495388-37-9',
#   u'dsstox_sid': u'DTXSID80737963',
#   u'jaccard': 0.9615384615384616,
#   u'name': u'N-(4-Hydroxyphenyl)acetamide--water (1/1)'},
#  {u'casrn': u'478080-38-5',
#   u'dsstox_sid': u'DTXSID10785235',
#   u'jaccard': 0.9615384615384616,
#   u'name': u'N-(4-Hydroxyphenyl)acetamide--water (1/3)'},
#  {u'casrn': u'666830-44-0',
#   u'dsstox_sid': u'DTXSID60792176',
#   u'jaccard': 0.9615384615384616,
#   u'name': u'N-(4-Hydroxyphenyl)acetamide--methanol (1/1)'},
#  {u'casrn': u'85153-38-4',
#   u'dsstox_sid': u'DTXSID10234293',
#   u'jaccard': 0.7272727272727273,
#   u'name': u'N-(4-((4-((4-Hydroxyphenyl)amino)phenyl)amino)phenyl)acetamide'},
#  {u'casrn': u'140-50-1',
#   u'dsstox_sid': u'DTXSID2059695',
#   u'jaccard': 0.6923076923076923,
#   u'name': u"Acetamide, N,N'-1,4-phenylenebis-"},
#  {u'casrn': u'57790-88-2',
#   u'dsstox_sid': u'DTXSID40357848',
#   u'jaccard': 0.6756756756756757,
#   u'name': u'STK156124'},
#  {u'casrn': u'489438-30-4',
#   u'dsstox_sid': u'DTXSID60786333',
#   u'jaccard': 0.6756756756756757,
#   u'name': u'N-(4-Hydroxyphenyl)acetamide--morpholine (2/5)'},
#  {u'casrn': u'613-35-4',
#   u'dsstox_sid': u'DTXSID9036854',
#   u'jaccard': 0.5806451612903226,
#   u'name': u"N,N'-Diacetylbenzidine"},
#  {u'casrn': u'2298-28-4',
#   u'dsstox_sid': u'DTXSID70291660',
#   u'jaccard': 0.5806451612903226,
#   u'name': u'1,3-bis(4-hydroxyphenyl)urea'},
#  {u'casrn': u'19243-95-9',
#   u'dsstox_sid': u'DTXSID40172836',
#   u'jaccard': 0.5714285714285714,
#   u'name': u"Acrylanilide, 4'-hydroxy-2-methyl-"},
#  {u'casrn': u'98996-33-9',
#   u'dsstox_sid': u'DTXSID80669997',
#   u'jaccard': 0.5714285714285714,
#   u'name': u'2-Hydroxy-N-(4-hydroxyphenyl)propanamide'},
#  {u'casrn': u'103-89-9',
#   u'dsstox_sid': u'DTXSID6024414',
#   u'jaccard': 0.5625,
#   u'name': u'N-Acetyl-p-toluidine'},
#  {u'casrn': u'103-88-8',
#   u'dsstox_sid': u'DTXSID6059283',
#   u'jaccard': 0.5625,
#   u'name': u'Acetamide, N-(4-bromophenyl)-'},
#   u'name': u'Butanamide, N-(4-hydroxyphenyl)-'},
#  {u'casrn': u'54840-15-2',
#   u'dsstox_sid': u'DTXSID20373526',
#   u'jaccard': 0.5,
#   u'name': u'4-N-Boc-aminophenol'},
#  {u'casrn': u'23159-73-1',
#   u'dsstox_sid': u'DTXSID60499936',
#   u'jaccard': 0.5,
#   u'name': u"N-(4-Hydroxyphenyl)-N'-propan-2-ylurea"},
#  {u'casrn': u'34443-04-4',
#   u'dsstox_sid': u'DTXSID00188014',
#   u'jaccard': 0.5,
#   u'name': u"Acrylanilide, 4'-hydroxy-"},
#  {u'casrn': u'6340-87-0',
#   u'dsstox_sid': u'DTXSID30212816',
#   u'jaccard': 0.5,
#   u'name': u'Triclacetamol [INN:DCF]'},
#  {u'casrn': u'2153-11-9',
#   u'dsstox_sid': u'DTXSID60284728',
#   u'jaccard': 0.5,
#   u'name': u'2-chloro-N-(4-hydroxyphenyl)acetamide'},
#  {u'casrn': u'1170-53-2',
#   u'dsstox_sid': u'DTXSID50288270',
#   u'jaccard': 0.5,
#   u'name': u"n,n'-bis(4-hydroxyphenyl)benzene-1,4-dicarboxamide"},
#  {u'casrn': u'2709-93-5',
#   u'dsstox_sid': u'DTXSID60313441',
#   u'jaccard': 0.5,
#   u'name': u'2,2,2-trifluoro-N-(4-hydroxyphenyl)acetamide'}]

# %%
searchFP('DTXSID6025486',DB=DB,s0=0.2,fp='bio_txct')
# Out:
# [{u'casrn': u'51-30-9',
#   u'dsstox_sid': u'DTXSID6025486',
#   u'jaccard': 1.0,
#   u'name': u'Isoproterenol hydrochloride'},
#  {u'casrn': u'126-11-4',
#   u'dsstox_sid': u'DTXSID8027034',
#   u'jaccard': 0.2318840579710145,
#   u'name': u'2-(Hydroxymethyl)-2-nitro-1,3-propanediol'},
#  {u'casrn': u'2243-62-1',
#   u'dsstox_sid': u'DTXSID3020916',
#   u'jaccard': 0.22935779816513763,
#   u'name': u'1,5-Naphthalenediamine'},
#  {u'casrn': u'1111-78-0',
#   u'dsstox_sid': u'DTXSID9027360',
#   u'jaccard': 0.22580645161290322,
#   u'name': u'Ammonium carbamate'},
#  {u'casrn': u'375-85-9',
#   u'dsstox_sid': u'DTXSID1037303',
#   u'jaccard': 0.2054794520547945,
#   u'name': u'Perfluoroheptanoic acid'},
#  {u'casrn': u'67-20-9',
#   u'dsstox_sid': u'DTXSID7020972',
#   u'jaccard': 0.20408163265306123,
#   u'name': u'Nitrofurantoin'},
#  {u'casrn': u'3252-43-5',
#   u'dsstox_sid': u'DTXSID3024940',
#   u'jaccard': 0.203125,
#   u'name': u'Dibromoacetonitrile'}]

# %%
DB.tox1_fp.find_one()
# Out:
# {u'_id': ObjectId('56d9da9814fd09250ac2fe7f'),
#  u'casrn': u'103-90-2',
#  u'dsstox_cid': u'DTXCID606',
#  u'name': u'Acetaminophen',
#  u'tox1': {u'ds': [u'SUB:liver',
#    u'SUB:lymph_node',
#    u'MGR:offspring_survival-early',
#    u'SUB:uterus',
#    u'SUB:body_weight',
#    u'CHR:thyroid_gland',
#    u'MGR:pituitary_gland',
#    u'SUB:mortality',
#    u'MGR:liver',
#    u'MGR:reproductive_performance',
#    u'SUB:testes',
#    u'MGR:body_weight',
#    u'SAC:body_weight',
#    u'SUB:ovary',
#    u'CHR:tissue_nos',
#    u'CHR:kidney',
#    u'SUB:thymus',
#    u'MGR:brain',
#    u'CHR:body_weight',
#    u'MGR:sperm_morphology',
#    u'SAC:food_consumption',
#    u'SUB:kidney',
#    u'SUB:food_consumption',
#    u'SUB:clinical_signs',
#    u'CHR:parathyroid_gland'],
#   u'n': 25},
#  u'toxq1': {u'CHR:[not_in_list]': 0.0,
#   u'CHR:abdominal_cavity': 0.0,
#   u'CHR:adrenal_gland': 0.0,
#   u'CHR:artery_(general)': 0.0,
#   u'CHR:auditory_startle_reflex_habituation': 0.0,
#   u'CHR:bile_duct': 0.0,
#   u'CHR:blood': 0.0,
#   u'CHR:blood_vessel': 0.0,
#   u'CHR:body_weight': 90.0,
#   u'CHR:bone': 0.0,
#   u'CHR:bone_marrow': 0.0,
#   u'CHR:brain': 0.0,
#   u'CHR:bronchus': 0.0,
#   u'CHR:cervix': 0.0,
#   u'CHR:clinical_chemistry': 0.0,
#   u'CHR:clinical_signs': 0.0,
#   u'CHR:clitoral_gland': 0.0,
#   u'CHR:coagulating_gland': 0.0,
#   u'CHR:ear': 0.0,
#   u'CHR:epididymis': 0.0,
#   u'CHR:esophagus': 0.0,
#   u'CHR:estrous_cycle': 0.0,
#   u'CHR:eye': 0.0,
#   u'CHR:food_consumption': 0.0,
#   u'CHR:gallbladder': 0.0,
#   u'CHR:general': 0.0,
#   u'CHR:harderian_gland': 0.0,
#   u'CHR:heart': 0.0,
#   u'CHR:hematology': 0.0,
#   u'CHR:intestine_large': 0.0,
#   u'CHR:intestine_small': 0.0,
#   u'CHR:kidney': 30.0,
#   u'CHR:lacrimal_gland': 0.0,
#   u'CHR:larynx': 0.0,
#   u'CHR:liver': 0.0,
#   u'CHR:locomotion': 0.0,
#   u'CHR:lung': 0.0,
#   u'CHR:lymph_node': 0.0,
#   u'CHR:mammary_gland': 0.0,
#   u'CHR:mesentery': 0.0,
#   u'CHR:mortality': 0.0,
#   u'CHR:motor_activity': 0.0,
#   u'CHR:nerve': 0.0,
#   u'CHR:nose': 0.0,
#   u'CHR:oral_mucosa': 0.0,
#   u'CHR:other': 0.0,
#   u'CHR:ovary': 0.0,
#   u'CHR:pancreas': 0.0,
#   u'CHR:parathyroid': 0.0,
#   u'CHR:parathyroid_gland': 30.0,
#   u'CHR:penis': 0.0,
#   u'CHR:peritoneum': 0.0,
#   u'CHR:pharynx': 0.0,
#   u'CHR:pituitary_gland': 0.0,
#   u'CHR:pleura': 0.0,
#   u'CHR:preputial_gland': 0.0,
#   u'CHR:prostate': 0.0,
#   u'CHR:reflexes': 0.0,
#   u'CHR:salivary_glands': 0.0,
#   u'CHR:seminal_vesicle': 0.0,
#   u'CHR:skeletal_muscle': 0.0,
#   u'CHR:skin': 0.0,
#   u'CHR:sperm_measure': 0.0,
#   u'CHR:sperm_morphology': 0.0,
#   u'CHR:spinal_cord': 0.0,
#   u'CHR:spleen': 0.0,
#   u'CHR:stomach': 0.0,
#   u'CHR:testes': 0.0,
#   u'CHR:thymus': 0.0,
#   u'CHR:thyroid_gland': 90.0,
#   u'CHR:tissue_nos': 35.0,
#   u'CHR:tongue': 0.0,
#   u'CHR:tooth': 0.0,
#   u'CHR:trachea': 0.0,
#   u'CHR:uncertain_primary_site': 0.0,
#   u'CHR:ureter': 0.0,
#   u'CHR:urethra': 0.0,
#   u'CHR:urinalysis': 0.0,
#   u'CHR:urinary_bladder': 0.0,
#   u'CHR:uterus': 0.0,
#   u'CHR:vagina': 0.0,
#   u'CHR:water_consumption': 0.0,
#   u"CHR:zymbal's_gland": 0.0,
#   u'MGR:[clinical]': 0.0,
#   u'MGR:[not_in_list]': 0.0,
#   u'MGR:adrenal_gland': 0.0,
#   u'MGR:age_landmark': 0.0,
#   u'MGR:auditory_startle_reflex_habituation': 0.0,
#   u'MGR:blood': 0.0,
#   u'MGR:body_weight': 357.0,
#   u'MGR:bone': 0.0,
#   u'MGR:bone_marrow': 0.0,
#   u'MGR:brain': 1430.0,
#   u'MGR:cervix': 0.0,
#   u'MGR:clinical_chemistry': 0.0,
#   u'MGR:clinical_signs': 0.0,
#   u'MGR:coagulating_gland': 0.0,
#   u'MGR:coordination': 0.0,
#   u'MGR:developmental_landmark': 0.0,
#   u'MGR:diaphragm': 0.0,
#   u'MGR:ear': 0.0,
#   u'MGR:epididymis': 0.0,
#   u'MGR:esophagus': 0.0,
#   u'MGR:estrous_cycle': 0.0,
#   u'MGR:estrous_cycle_length': 0.0,
#   u'MGR:eye': 0.0,
#   u'MGR:food_consumption': 0.0,
#   u'MGR:general': 0.0,
#   u'MGR:gonad': 0.0,
#   u'MGR:hair_growth': 0.0,
#   u'MGR:heart': 0.0,
#   u'MGR:hematology': 0.0,
#   u'MGR:intestine_large': 0.0,
#   u'MGR:intestine_small': 0.0,
#   u'MGR:kidney': 0.0,
#   u'MGR:limb': 0.0,
#   u'MGR:liver': 1430.0,
#   u'MGR:locomotion': 0.0,
#   u'MGR:lung': 0.0,
#   u'MGR:lymph_node': 0.0,
#   u'MGR:mammary_gland': 0.0,
#   u'MGR:maternal_wastage': 0.0,
#   u'MGR:maze': 0.0,
#   u'MGR:mortality': 0.0,
#   u'MGR:motor_activity': 0.0,
#   u'MGR:mouth_/_jaw': 0.0,
#   u'MGR:nerve': 0.0,
#   u'MGR:nose': 0.0,
#   u'MGR:offspring_survival-early': 1430.0,
#   u'MGR:offspring_survival-late': 0.0,
#   u'MGR:other': 0.0,
#   u'MGR:ovary': 0.0,
#   u'MGR:pancreas': 0.0,
#   u'MGR:parathyroid': 0.0,
#   u'MGR:parathyroid_gland': 0.0,
#   u'MGR:paw_/_digit': 0.0,
#   u'MGR:penis': 0.0,
#   u'MGR:pituitary_gland': 1430.0,
#   u'MGR:placenta': 0.0,
#   u'MGR:prostate': 0.0,
#   u'MGR:reflexes': 0.0,
#   u'MGR:reproductive_outcome': 0.0,
#   u'MGR:reproductive_performance': 1430.0,
#   u'MGR:salivary_glands': 0.0,
#   u'MGR:seminal_vesicle': 0.0,
#   u'SUB:uncertain_primary_site': 0.0,
#   u'SUB:ureter': 0.0,
#   u'SUB:urethra': 0.0,
#   u'SUB:urinalysis': 0.0,
#   u'SUB:urinary_bladder': 0.0,
#   u'SUB:uterus': 1250.0,
#   u'SUB:vagina': 0.0,
#   u'SUB:water_consumption': 0.0}}

# %%
searchFP('DTXSID2020006',DB=DB,s0=0.2,fp='toxp_txrf',sel_by='toxp_txrf')
# Out:
# [{u'dsstox_sid': u'DTXSID2020006', u'jaccard': 1.0, u'name': u'Acetaminophen'},
#  {u'dsstox_sid': u'DTXSID5020863',
#   u'jaccard': 0.3225806451612903,
#   u'name': u'Methyldopa sesquihydrate'},
#  {u'dsstox_sid': u'DTXSID7024160',
#   u'jaccard': 0.3076923076923077,
#   u'name': u'Lactofen'},
#  {u'dsstox_sid': u'DTXSID0024216',
#   u'jaccard': 0.3023255813953488,
#   u'name': u'Nitrapyrin'},
#  {u'dsstox_sid': u'DTXSID2034627',
#   u'jaccard': 0.2923076923076923,
#   u'name': u'Fluroxypyr'},
#  {u'dsstox_sid': u'DTXSID7024245',
#   u'jaccard': 0.2894736842105263,
#   u'name': u'Pendimethalin'},
#  {u'dsstox_sid': u'DTXSID0021961',
#   u'jaccard': 0.2857142857142857,
#   u'name': u'Benzophenone'},
#  {u'dsstox_sid': u'DTXSID4032667',
#   u'jaccard': 0.2826086956521739,
#   u'name': u'Esfenvalerate'},
#  {u'dsstox_sid': u'DTXSID4032532',
#   u'jaccard': 0.2777777777777778,
#   u'name': u'Carfentrazone-ethyl'},
#  {u'dsstox_sid': u'DTXSID4039235',
#   u'jaccard': 0.27586206896551724,
#   u'name': u'1-Amino-2,4-dibromoanthraquinone'},
#  {u'dsstox_sid': u'DTXSID8021808',
#   u'jaccard': 0.27586206896551724,
#   u'name': u'o-Cresol'},
#  {u'dsstox_sid': u'DTXSID6024836',
#   u'jaccard': 0.275,
#   u'name': u'3,7-Dimethyl-2,6-octadienal'},
#  {u'dsstox_sid': u'DTXSID6021248',
#   u'jaccard': 0.2727272727272727,
#   u'name': u'Rotenone'},
#  {u'dsstox_sid': u'DTXSID7020346',
#   u'jaccard': 0.2708333333333333,
#   u'name': u'Copper-8-hydroxyquinoline (1:2)'},
#  {u'dsstox_sid': u'DTXSID2034384',
#   u'jaccard': 0.2708333333333333,
#   u'name': u'Borax'},
#  {u'dsstox_sid': u'DTXSID3024316',
#   u'jaccard': 0.2702702702702703,
#   u'name': u'Tebuthiuron'},
#  {u'dsstox_sid': u'DTXSID7032638',
#   u'jaccard': 0.26666666666666666,
#   u'name': u'Pyraclostrobin'},
#  {u'dsstox_sid': u'DTXSID9020582',
#   u'jaccard': 0.2647058823529412,
#   u'name': u'Ethoxyquin'},
#  {u'dsstox_sid': u'DTXSID0020494',
#   u'jaccard': 0.2647058823529412,
#   u'name': u'Dimethyl methylphosphonate'},
#  {u'dsstox_sid': u'DTXSID9023881',
#   u'jaccard': 0.2619047619047619,
#   u'name': u'Clofentezine'},
#  {u'dsstox_sid': u'DTXSID4034653',
#   u'jaccard': 0.2619047619047619,
#   u'name': u'Hexaconazole'},
#   u'name': u'1,2-Benzenedicarboxaldehyde'},
#  {u'dsstox_sid': u'DTXSID7024902',
#   u'jaccard': 0.2127659574468085,
#   u'name': u'Dazomet'},
#  {u'dsstox_sid': u'DTXSID0021337',
#   u'jaccard': 0.2127659574468085,
#   u'name': u'Thiabendazole'},
#  {u'dsstox_sid': u'DTXSID9032610',
#   u'jaccard': 0.21212121212121213,
#   u'name': u'Etofenprox'}]

# %% [markdown]
# ## Test out getfp

# %%
from db.getfp import *

# %%
X = getFP(['DTXSID2020006'],fp='toxp_txrf',DB=DB,fill=0)
X
# Out:
# fp             CHR:Body Weight  CHR:Kidney  CHR:Parathyroid Gland  \
# dsstox_sid
# DTXSID2020006                1           1                      1
#
# fp             CHR:Thyroid Gland  CHR:Tissue NOS  MGR:Body Weight  MGR:Brain  \
# dsstox_sid
# DTXSID2020006                  1               1                1          1
#
# fp             MGR:Liver  MGR:Offspring Survival-Early  MGR:Pituitary Gland  \
# dsstox_sid
# DTXSID2020006          1                             1                    1
#
# fp                ...      SUB:Clinical Signs  SUB:Food Consumption  \
# dsstox_sid        ...
# DTXSID2020006     ...                       1                     1
#
# fp             SUB:Kidney  SUB:Liver  SUB:Lymph Node  SUB:Mortality  \
# dsstox_sid
# DTXSID2020006           1          1               1              1
#
# fp             SUB:Ovary  SUB:Testes  SUB:Thymus  SUB:Uterus
# dsstox_sid
# DTXSID2020006          1           1           1           1
#
# [1 rows x 25 columns]

# %%
X = getFP(['DTXSID2020006'],fp='toxn_txrf',DB=DB,fill=0)
X
# Out:
# fp             CHR:Abdominal Cavity  CHR:Adrenal Gland  CHR:Artery (General)  \
# dsstox_sid
# DTXSID2020006                     1                  1                     1
#
# fp             CHR:Auditory Startle Reflex Habituation  CHR:Bile duct  \
# dsstox_sid
# DTXSID2020006                                        1              1
#
# fp             CHR:Blood  CHR:Blood vessel  CHR:Bone  CHR:Bone Marrow  \
# dsstox_sid
# DTXSID2020006          1                 1         1                1
#
# fp             CHR:Brain        ...          SUB:Tooth  SUB:Trachea  \
# dsstox_sid                      ...
# DTXSID2020006          1        ...                  1            1
#
# fp             SUB:Uncertain Primary Site  SUB:Ureter  SUB:Urethra  \
# dsstox_sid
# DTXSID2020006                           1           1            1
#
# fp             SUB:Urinalysis  SUB:Urinary Bladder  SUB:Vagina  \
# dsstox_sid
# DTXSID2020006               1                    1           1
#
# fp             SUB:Water Consumption  SUB:[Not In List]
# dsstox_sid
# DTXSID2020006                      1                  1
#
# [1 rows x 288 columns]

# %%
from db.fpsim import *

# %%
from rax.genrapred import *

# %%
help(runGenRA)
# Out:
# Help on function runGenRA in module rax.genrapred:
#
# runGenRA(cid, Y=None, CID=None, DB=None, fp_x='chm_mrgn', fp_y='toxp_txrf', sel_by=None, k0=10, s0=0.1, metric='jaccard', pred=True, ret=None, wt=True, n_perm=100)
#     cid  : the DSSTOX CID of the target chemical (required)
#
#     Y    : list of toxicities for evaluation of activities (optional)
#
#     CID  : list of dsstox_cids of chemicals to consider in neighbourhood (optional)
#
#     DB   : reference to mongodb (required)
#
#     fp_x : fingerprint for chemical similarity. Options:
#           - chm_mrgn: RDKit Morgan (default)
#           - chm_httr: RDKit Torsion
#           - chm_ct  : ChemoTypes
#
#     fp_y: fingerprint for predicted bioactivity. This is resolved to a specific
#           database collection and attribute. Currently only consider toxicity. Options
#           - toxp_txrf: toxref toxicity classifications.
#
#     sel_by: when finding nearest neighbours of target, select the neighbours based on
#             availability of this information. Options:
#           - tox_txrf: toxref toxicity classifications.
#
#     k0    : Number of nearest neighbours to consider
#
#     s0    : Similarity threshold measured by metric
#
#     metric: Similarity metric. Options:
#           - Jaccard (default)
#
#     n_perm: Number of permutations for testing significance of AUC
#
#     pred  : Whether to predict activity for target or just calculate the
#             predictive performances
#
#     ret   : Results to return. Options:
#           - full: a list with three elements
#             1. Predictions for target
#             2. Performance results for neighbourhood
#             3. Similarity scores for chemicals in neighbourhood
#           - else:
#             * Performance results
#
#     Description of returned values:
#
#     * Predictions for target - a list of predictions, one for each bioactivity outcome.
#       Each prediction is a dict with the following keys:
#       - dsstox_cid  : DSSTOX CID of target
#       - out         : bioactivity/toxicity endpoint
#       - k0          : k0
#       - s0          : s0
#       - fp          : fp_x
#       - a_t         : Observed activity of target for out
#       - a_s         : Similarity weighted bioactivity of target across neighbours
#       - a_p         : Predicted activity 0/1 based on threshold t0
#       - auc         : ROC area under curve across a_s and a_t for neighbours
#       - t0          : activity threshold that produces best balanced accuracy
#       - p_val       : the significance of auc across n_perm
#       - pred        : the prediction class
#                       if a_t known  : one of TN/TP/FN/FP
#                       if a_t unknown: one of Pos/Neg
#
#     * Performance results for neighbourhood as a dict in which keys are
#       bioactivity/toxicity endpoints and values are dictionaries with the following
#       keys:
#       - out        : Binary activity of each analog (no effect:0/effect: 1)
#       - act        : Similarity weighted activities for each analog in the
#                      neighbourhood as a pandas.DataFrame with the following columns:
#              - dsstox_cid: DSSTOX CID of analog (index)
#              - a_t       : True activity of analog
#              - a_p       : Simiarity weighted bioactivity of analog
#              - n_p       : Number of positives
#              - n_n       : Number of negatives
#       - roc        : The receiver operating characteristic for the neighbourhood
#                      as a dataframe with the following columns:
#              - fpr       : false positive rate
#              - sp        : specificity
#              - sn        : sensitivity
#              - t0        : score threshold
#              - BA        : balanced accuracy = 0.5 * (sn+sp)
#
#     * Similarity matrix for all k0 chemicals considered in neighbourhood as a
#       k0xk0 pandas.DataFrame in which rows and columns are indexed by dsstox_cid and
#       the value of each cell is the similarity score based on above metric

# %%
SID = [i['dsstox_sid'] for i in searchFP('DTXSID2020006',DB=DB,s0=0.01,fp='chm_mrgn')]
DB.tox_fp.find({'dsstox_sid':{'$in':SID}}).count()
# Out:
# 1

# %%
Hits = pd.DataFrame(runGenRA('DTXSID3023180',DB=DB,s0=0.05,k0=20,dbg=False,sel_by='toxp_txrf'))

# %%
Hits.sort_values(['auc','p_val'],ascending=[False,True]).query("p_val<0.2").head(10)
# Out:
#      a_p    a_s   a_t       auc     dsstox_sid        fp  k0  n_neg  n_pos  \
# 100    1  0.087  None  0.857143  DTXSID3023180  chm_mrgn  20     14      2
#
#             out  p_val pred    s0        t0
# 100  MGR:Spleen   0.02  Pos  0.05  0.086061
