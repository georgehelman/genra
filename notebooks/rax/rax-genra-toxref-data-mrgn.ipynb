# %%
import pandas as pd
import numpy as np
import pymongo
import sys
import os
from __future__ import print_function
from datetime import datetime
import matplotlib.pyplot as plt

TOP = '/'.join(os.getcwd().split('/')[:-2])+'/'
LIB = TOP+'lib'
if not LIB in sys.path: 
    sys.path.insert(0,LIB)

DAT_DIR = TOP + 'data/toxref/'
FIG_DIR = TOP + 'figs/toxref/'

from rax.genrapred import *

# %%
mongocon=pymongo.MongoClient("mongodb://ghelman:ghelman@pb.epa.gov/genra_dev_v4")
DB=mongocon['genra_dev_v4']
dsstox=DB['compound']
toxref=DB['toxrefdb2']
physprop=DB['physprop']

# %%
def wtavg(df,name,k,s):
    df=df[df['jaccard']>s]
    df=df[df[name]!=np.inf]
    df=df[df[name].notnull()].iloc[0:k]
    if df.empty:
        return np.nan
    weights=list(df['jaccard'])
    values=list(df[name])
    return np.average(values,weights=weights)

# %%
def exact_k_wtavg(df,name,k,s):
    df=df[df['jaccard']>s]
    df=df[df[name]!=np.inf]
    df=df[df[name].notnull()].iloc[0:k]
    if len(df)<k:
        return np.nan
    weights=list(df['jaccard'])
    values=list(df[name])
    return np.average(values,weights=weights)

# %%
from __future__ import division
ks=range(1,20)
ss=[round(s/20,2) for s in range(1,20)]

# %% [markdown]
# <h1>EDA</h1>

# %%
print(str(toxref.count()) + ' total substances')
# Out:
# 1076 total substances

# %%
def pod_record(document):
    pods=document['pods']
    for pod in pods:
        pod['dsstox_sid']=document['dsstox_sid']
    return pods

# %%
pods_df=pd.DataFrame([pod for document in toxref.find() for pod in pod_record(document)])
#pods_df=pods_df[pods_df['effect_profile_id']==2] #Turns out they all equal 2

# %%
#Need to convert to log molar
sids=list(pods_df['dsstox_sid'].unique())
weights={record['dsstox_sid']:record['mol_weight'] for record in dsstox.find({'dsstox_sid':{'$in':sids}})}
pods_df['mol_weight']=pods_df['dsstox_sid'].map(weights)
pods_df['pod_value_LM']=-np.log10(pods_df['pod_value']/pods_df['mol_weight']/1000)
# Out:
# /share/home/ghelman/workspace/anaconda2/envs/my-rdkit-env/lib/python2.7/site-packages/ipykernel/__main__.py:5: RuntimeWarning: divide by zero encountered in log10

# %%
loael_df=pods_df[pods_df['pod_type']=='loael']
loael_df=loael_df[loael_df['pod_unit']=='mg/kg/day']
loael_df.to_csv(DAT_DIR+'loael.csv',encoding='utf-8')

# %%
print(str(len(loael_df))+ ' LOAEL values')
print(str(loael_df['dsstox_sid'].nunique()) + ' unique chemicals')
# Out:
# 27546 LOAEL values
# 1049 unique chemicals

# %%
loael_agg=loael_df.pivot_table(index='dsstox_sid',columns='endpoint_category',values='pod_value_LM',aggfunc='min')
print(str(len(loael_agg)) + ' chemicals found DSSTox matches to obtain their mol weights')
loael_agg.to_csv(DAT_DIR+'loaelagg.csv',encoding='utf-8')
# Out:
# 1014 chemicals found DSSTox matches to obtain their mol weights

# %%
loael_sids=list(set(loael_agg.index.values))
categories=list(loael_agg.columns.values)

# %%
with pd.option_context('display.max_columns',None):
    loael_df[~loael_df['dsstox_sid'].isin(loael_sids)]
# Out:
#              casrn  chemical_id chemical_id_type  direction  dose_level  \
# 11491                                       dead fetuses
# 11492                                  total litter loss
# 11498                                   body weight gain
# 11499                                           erythema
# 13313                                        body weight
# 13314                                   body weight gain
# 13315                                   food consumption
# 13325                                        hypertrophy
# 13332                                        hypertrophy
# 13333                                    colloid content
# 21834                                        body weight
# 21835                                   body weight gain
# 21842                                        cholesterol
# 21843                                        cholesterol
# 21844                                            [other]
# 21845                                            [other]
# 21854                                           cataract
# 21855                                           cataract
# 21861                                           absolute
# 21862                            relative to body weight
# 21863                            reduced spermatogenesis
# ...                                                  ...
# 98928                            relative to body weight
# 98935                                          nodule(s)
# 98936                                         discolored
# 98943                   hematopoietic cell proliferation
# 98947                                           enlarged
# 98951                                              edema
# 98963                                  erythrocyte (rbc)
# 98964                                   hematocrit (hct)
# 98965                                   hemoglobin (hgb)
# 98975                                         dilatation
# 98983                                     mineralization
# 98984                                     mineralization
# 98990                                    hemangiosarcoma
# 98994                                                nos
# 98995                                    lesion(s) (nos)
# 99001                                            [other]
# 99005                                    lesion(s) (nos)
# 99009                                       inflammation
# 99022                                               mass
# 99023                                               mass
# 100699                                           [other]
# 100700                                           [other]
# 101771                                            mating
# 101772                                            mating
# 101773                                            mating
# 101781                                  food consumption
# 101782                                  food consumption
# 101787                                      testosterone
# 101791                                       hypertrophy
# 101792                                          necrosis
#
#                                          effect_desc_free  effect_id  \
# 3951                                                   NA       1768
# 3955                                                   NA       1971
# 3960                                                   NA        102
# 3964                                                   NA        119
# 3965                                                   NA       1910
# 3972                                                   NA        190
# 3973                                                   NA        238
# 3974                                                   NA        161
# 3975                                                   NA       1666
# 11491                                                  NA       2095
# 11492                                                  NA        977
# 11498                                                  NA        320
# 11499                                   Dermal irritation       1613
# 13313                                                  NA       1768
# 13314                                                  NA        320
# 13315                                                  NA       1380
# 13325                                          Panlobular        826
# 13332                                                  NA       1462
# 13333                                             Altered        589
# 21834                    one animal lost 1.3 kg of weight       1768
# 21835                    one animal lost 1.3 kg of weight        320
# 21842                                          in week 29        566
# 21843                                          in week 29        566
# 21844                             Desmesterol; in week 29       2125
# 21845                             Desmesterol; in week 29       2125
# 21854   In week 30, one animal showed fine, dot-like o...        502
# 21855   In week 53, one animal showed fine, dot-like, ...        502
# 21861                                                  NA       1790
# 21862                                                  NA       2223
# 21863                          spermatogenesis inhibition       2572
# ...                                                   ...        ...
# 98928                                                  NA       2571
# 98935                            In 1 dog that died; Firm       1947
# 98936                            In 1 dog that died; Pale       2772
# 98943                                                  NA       2618
# 98947                     In 1 dog that died; Prescapular       2770
# 98951                                      Clinical signs       2270
# 98963                                                  NA        524
# 98964                                                  NA       1226
# 98965                                                  NA       2283
# 98975                                                  NA       2554
# 98983                                               1 dog        766
# 98984                                               1 dog        766
# 98990                                                  NA        275
# 98994                                               1 dog        739
# 98995   Reduced to a thin strand of tissue & caput was...       2539
# 99001                                       hemosiderosis       1419
# 99005       Traumatized (unclear from DER what was meant)       2847
# 99009                                                  NA       1385
# 99022                                  1 dog; Oral cavity        696
# 99023                                  1 dog; Oral cavity        696
# 100699                            mucoid bronchopneumonia        297
# 100700                            mucoid bronchopneumonia        297
# 98928           100                                     adrenal gland
# 98935            75                                              lung
# 98936            75                                              lung
# 98943           334                                            spleen
# 98947           358                                        lymph node
# 98951           393                                              skin
# 98963           371              erythrocyte (rbc) count differential
# 98964           219                                  hematocrit (hct)
# 98965           228                                  hemoglobin (hgb)
# 98975            21                                       gallbladder
# 98983           302                                             nerve
# 98984           302                                             nerve
# 98990           194                                             ovary
# 98994           115                                        epididymis
# 98995           369                                        epididymis
# 99001           382                                           [other]
# 99005           279                                               ear
# 99009            89                                   intestine large
# 99022           232                                       oral mucosa
# 99023           232                                       oral mucosa
# 100699          139                                              lung
# 100700          139                                              lung
# 101771          156                                            mating
# 101772          156                                            mating
# 101773          156                                            mating
# 101781           44                                  food consumption
# 101782           44                                  food consumption
# 101787          273                                      testosterone
# 101791          137                                             liver
# 101792          137                                             liver
#
#                    endpoint_type group_description  group_id  \
# 3951         in life observation              None         6
# 3955          clinical chemistry              None         4
# 3960                organ weight              None        19
# 3964                organ weight              None        20
# 3965                organ weight              None        20
# 3972                  hematology              None         5
# 3973                  hematology              None         5
# 3974                  hematology              None         5
# 3975                  hematology              None         5
# 11491   offspring survival early              None         3
# 11492   offspring survival early              None         3
# 11498        in life observation              None         6
# 11499        in life observation              None         6
# 13313        in life observation              None         6
# 13314        in life observation              None         6
# 13315        in life observation              None         6
# 13325      pathology microscopic              None        20
# 13332      pathology microscopic              None        64
# 13333      pathology microscopic              None        64
# 21834        in life observation              None         6
# 21835        in life observation              None         6
# 21842         clinical chemistry              None         4
# 21843         clinical chemistry              None         4
# 21844         clinical chemistry              None         4
# 21845         clinical chemistry              None         4
# 21854      pathology microscopic              None        14
# 21855      pathology microscopic              None        14
# 21861               organ weight              None        62
# 21862               organ weight              None        62
# 21863      pathology microscopic              None        62
# ...                          ...               ...       ...
# 98928               organ weight              None         9
# 98935            pathology gross              None        21
# 98936            pathology gross              None        21
# 98943      pathology microscopic              None        23
# 98947            pathology gross              None        37
# 98951      pathology microscopic              None        58
# 98963                 hematology              None         5
# 98964                 hematology              None         5
# 98965                 hematology              None         5
# 98975      pathology microscopic              None        15
# 98983      pathology microscopic              None        39
# 98984      pathology microscopic              None        39
# 98990      pathology microscopic              None        42
# 98994               organ weight              None        30
# 98995            pathology gross              None        30
# 99001      pathology microscopic              None         8
# 99005            pathology gross              None        13
# 99009      pathology microscopic              None        17
# 99022            pathology gross              None        41
# 99023            pathology gross              None        41
# 100699     pathology microscopic              None        21
# 100700     pathology microscopic              None        21
# 101771  reproductive performance              None         3
# 101772  reproductive performance              None         3
# 101773  reproductive performance              None         3
# 101781       in life observation              None         6
# 101782       in life observation              None         6
# 101787        clinical chemistry              None         4
# 101791     pathology microscopic              None        20
# 101792     pathology microscopic              None        20
#
#                           group_name       life_stage  max_dose_level  \
# 3951    systemic/in life observation            adult               5
# 3955     systemic/clinical chemistry            adult               5
# 3960                          kidney            adult               5
# 3964                           liver            adult               5
# 3965                           liver            adult               5
# 3972             systemic/hematology            adult               5
# 3973             systemic/hematology            adult               5
# 3974             systemic/hematology            adult               5
# 3975             systemic/hematology            adult               5
# 98995     loael  mg/kg/day     75.000                   Polihexanide
# 99001     loael  mg/kg/day    275.000                   Polihexanide
# 99005     loael  mg/kg/day    715.000                   Polihexanide
# 99009     loael  mg/kg/day    167.000                   Polihexanide
# 99022     loael  mg/kg/day     75.000                   Polihexanide
# 99023     loael  mg/kg/day     75.000                   Polihexanide
# 100699    loael  mg/kg/day    240.000           Toluene diisocyanate
# 100700    loael  mg/kg/day    240.000           Toluene diisocyanate
# 101771    loael  mg/kg/day      5.000     Chlordane, technical grade
# 101772    loael  mg/kg/day      5.000     Chlordane, technical grade
# 101773    loael  mg/kg/day      5.000     Chlordane, technical grade
# 101781    loael  mg/kg/day      1.880     Chlordane, technical grade
# 101782    loael  mg/kg/day      1.880     Chlordane, technical grade
# 101787    loael  mg/kg/day      5.000     Chlordane, technical grade
# 101791    loael  mg/kg/day      0.045     Chlordane, technical grade
# 101792    loael  mg/kg/day      0.045     Chlordane, technical grade
#
#        qualifier  staggered_dosing study_id                target_site  \
# 3951           >                 0     None                         NA
# 3955           >                 0     None                         NA
# 3960           >                 0     None                         NA
# 3964           >                 0     None                         NA
# 3965           >                 0     None                         NA
# 3972           >                 0     None                         NA
# 3973           >                 0     None                         NA
# 3974           >                 0     None                         NA
# 3975           >                 0     None                         NA
# 11491        '='                 0     None                         NA
# 11492        '='                 0     None                         NA
# 11498        '='                 0     None                         NA
# 11499        '='                 0     None                         NA
# 13313          >                 0     None                         NA
# 13314          >                 0     None                         NA
# 13315          >                 0     None                         NA
# 13325        '='                 0     None                         NA
# 13332        '='                 0     None            follicular cell
# 13333        '='                 0     None                         NA
# 21834          >                 0     None                         NA
# 21835          >                 0     None                         NA
# 21842          >                 0     None                         NA
# 21843          >                 0     None                         NA
# 21844          >                 0     None                         NA
# 21845          >                 0     None                         NA
# 21854          >                 0     None                         NA
# 21855          >                 0     None                         NA
# 21861          >                 0     None                         NA
# 21862          >                 0     None                         NA
# 21863          >                 0     None                         NA
# ...          ...               ...      ...                        ...
# 98928          >                 0     None                         NA
# 98935          >                 0     None                         NA
# 98936          >                 0     None                         NA
# 98943          >                 0     None                         NA
# 98947          >                 0     None                         NA
# 98951        '='                 0     None  skin, site of application
# 98963          >                 0     None                         NA
# 98964          >                 0     None                         NA
# 98965          >                 0     None                         NA
# 98975        '='                 0     None                      lumen
# 98983          >                 0     None                     spinal
# 98984          >                 0     None                     spinal
# 98990          >                 0     None                         NA
# 98994          >                 0     None                         NA
# 98995          >                 0     None                         NA
# 99001          >                 0     None                         NA
# 99005          >                 0     None                      pinna
# 99009        '='                 0     None         anorectal junction
# 99022          >                 0     None                         NA
# 99023          >                 0     None                         NA
# 100699         >                 0     None                 bronchiole
# 100700         >                 0     None                 bronchiole
# 101771         >                 0     None                         NA
# 101772         >                 0     None                         NA
# 101773         >                 0     None                         NA
# 101781         >                 0     None                         NA
# 101782         >                 0     None                         NA
# 101787         >                 0     None                         NA
# 101791       '='                 0     None                 hepatocyte
# 101792       '='                 0     None                 hepatocyte
#
#         tg_effect_id  tg_id           timestamp  mol_weight  pod_value_LM
# 99022          94740  18194 2015-01-30 13:18:23         NaN           NaN
# 99023          94741  18195 2015-01-30 13:18:23         NaN           NaN
# 100699        145285  30696 2018-03-05 13:36:42         NaN           NaN
# 100700        145287  30697 2018-03-05 13:36:42         NaN           NaN
# 101771         91544  17488 2015-01-30 13:18:10         NaN           NaN
# 101772         91545  17488 2015-01-30 13:18:10         NaN           NaN
# 101773         91546  17488 2015-01-30 13:18:10         NaN           NaN
# 101781         38836   8057 2015-01-30 13:12:50         NaN           NaN
# 101782         38837   8059 2015-01-30 13:12:50         NaN           NaN
# 101787         91547  17487 2015-01-30 13:18:10         NaN           NaN
# 101791         38832   8055 2015-01-30 13:12:50         NaN           NaN
# 101792         38833   8055 2015-01-30 13:12:50         NaN           NaN
#
# [930 rows x 39 columns]

# %% [markdown]
# <h1>Make Data</h1>

# %%
loael_neighbors_l=[]
for sid in loael_sids:
    sid_neighbors=searchCollByFP(sid,s0=.05,SID=loael_sids,DB=DB)
    if sid_neighbors:
        for neighbor in sid_neighbors:
            neighbor['target_sid']=sid
            neighbor['neighbor_sid']=neighbor.pop('dsstox_sid')
        loael_neighbors_l=loael_neighbors_l+sid_neighbors

# %%
loael_neighbors=pd.DataFrame(loael_neighbors_l)
loael_neighbors=loael_neighbors[loael_neighbors['target_sid']!=loael_neighbors['neighbor_sid']]
loael_neighbors=loael_neighbors.merge(loael_agg,left_on='neighbor_sid',right_index=True)
loael_neighbors=loael_neighbors.sort_values('jaccard',ascending=False)
loael_neighbors.to_csv(DAT_DIR+'loael_neighbors_mrgn.csv')
#loael_neighbors=pd.read_csv(DAT_DIR+'loael_neighbors_mrgn.csv')
loael_neighbors.head()
# Out:
#             casrn  jaccard            name   neighbor_sid     target_sid  \
# 78973  57837-19-1      1.0       Metalaxyl  DTXSID6024175  DTXSID8032671
# 92026  51218-45-2      1.0     Metolachlor  DTXSID4022448  DTXSID6032431
# 30784  15165-67-0      1.0   Dichlorprop-P  DTXSID0034851  DTXSID0020440
# 29786  28434-00-6      1.0  S-Bioallethrin  DTXSID2039336  DTXSID8035180
# 61556     93-65-2      1.0        Mecoprop  DTXSID9024194  DTXSID3032670
#
#        cholinesterase  developmental  reproductive  systemic
# 78973             NaN       2.844067           NaN  3.048187
# 92026             NaN            NaN      2.453012  2.799800
# 30784             NaN       3.371179           NaN  2.982013
# 29786             NaN       3.781632      3.190567  2.706962
# 61556             NaN            NaN           NaN  3.656870

# %%
predictions={}
k=10
s=.05
for sid,group in loael_neighbors.groupby('target_sid'):
        predictions[sid]={category+'_p':wtavg(group,category,k,s) for category in categories}

# %%
loael_predictions.head()
# Out:
#                cholinesterase_p  developmental_p  reproductive_p  systemic_p  \
# DTXSID4047672          3.889967         3.493957        3.282332    2.941796
# DTXSID1020485          5.304208         3.041462        3.113375    2.607519
# DTXSID3024235          4.360391         3.965492        3.873737    2.985669
# DTXSID2044343          3.922568         4.112034        3.319040    2.991001
# DTXSID7030066          5.827070         2.901580        3.068403    3.351817
#
#                cholinesterase  developmental  reproductive  systemic
# DTXSID4047672             NaN       3.836210           NaN  2.842984
# DTXSID1020485             NaN            NaN           NaN  3.463920
# DTXSID3024235             NaN       5.896800      4.255822  4.067497
# DTXSID2044343             NaN       4.026338           NaN  2.964258
# DTXSID7030066             NaN            NaN           NaN  9.230972

# %%
loael_predictions=pd.DataFrame(predictions.values(),index=predictions.keys())
loael_predictions=loael_predictions.merge(loael_agg,right_index=True,left_index=True)
print(str(len(loael_predictions))+' chemicals successfully predicted')
print(str(len(loael_df[loael_df['dsstox_sid'].isin(loael_predictions.index)])) + ' associated LOAEL values')
loael_predictions.describe()
loael_predictions.to_csv(DAT_DIR+'loael_predictions_mrgn.csv')
# Out:
# 1004 chemicals successfully predicted
# 26444 associated LOAEL values
#        cholinesterase_p  developmental_p  reproductive_p   systemic_p  \
# count        990.000000      1002.000000     1002.000000  1003.000000
# mean           4.497893         3.387018        3.375043     2.919175
# std            0.815091         0.515842        0.509770     0.534465
# min            2.271297         1.734318        1.502154     1.554868
# 25%            3.943706         3.055121        3.053886     2.600838
# 50%            4.407326         3.357345        3.338559     2.857601
# 75%            5.009778         3.690819        3.653302     3.141854
# max            6.989261         5.174729        5.054443     4.978817
#
#        cholinesterase  developmental  reproductive    systemic
# count       84.000000     472.000000    431.000000  996.000000
# mean         5.045443       3.520007      3.510849    3.031798
# std          1.482639       0.999660      1.041681    0.997426
# min          2.271297       0.618623      0.875650    0.047981
# 25%          3.937997       2.866933      2.858890    2.358246
# 50%          5.178954       3.456329      3.424777    2.878940
# 75%          6.411867       4.051531      4.001633    3.562107
# max          7.566654       7.772923      8.490874    9.507802

# %% [markdown]
# <h1>Mean Aggregation</h1>

# %%
loael_agg_mean=loael_df.pivot_table(index='dsstox_sid',columns='endpoint_category',values='pod_value_LM',aggfunc='mean')
loael_agg_sd=loael_df.pivot_table(index='dsstox_sid',columns='endpoint_category',values='pod_value_LM',aggfunc='std')
loael_agg_sd=loael_agg_sd.loc[loael_agg_mean.index]
loael_agg_mean.to_csv(DAT_DIR+'loael_agg_mean_mrgn.csv')
loael_agg_sd.to_csv(DAT_DIR+'loael_agg_sd_mrgn.csv')
# Out:
# /share/home/ghelman/workspace/anaconda2/envs/my-rdkit-env/lib/python2.7/site-packages/ipykernel/__main__.py:3: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   app.launch_new_instance()

# %%
loael_neighbors_mean=pd.DataFrame(loael_neighbors_l)
loael_neighbors_mean=loael_neighbors_mean[loael_neighbors_mean['target_sid']!=loael_neighbors_mean['neighbor_sid']]
loael_neighbors_mean=loael_neighbors_mean.merge(loael_agg_mean,left_on='neighbor_sid',right_index=True)
loael_neighbors_mean=loael_neighbors_mean.sort_values('jaccard',ascending=False)
loael_neighbors_mean.to_csv(DAT_DIR+'loael_neighbors_mean_mrgn.csv')

# %%
loael_neighbors_sd=pd.DataFrame(loael_neighbors_l)
loael_neighbors_sd=loael_neighbors_sd[loael_neighbors_sd['target_sid']!=loael_neighbors_sd['neighbor_sid']]
loael_neighbors_sd=loael_neighbors_sd.merge(loael_agg_sd,left_on='neighbor_sid',right_index=True)
loael_neighbors_sd=loael_neighbors_sd.loc[loael_neighbors_mean.index]
loael_neighbors_sd.to_csv(DAT_DIR+'loael_neighbors_sd_mrgn.csv')

# %%
predictions_mean={}
k=10
s=.05
for sid,group in loael_neighbors_mean.groupby('target_sid'):
    predictions_mean[sid]={category+'_p':wtavg(group,category,k,s) for category in categories}

# %%
predictions_sd={}
k=10
for sid,group in loael_neighbors_sd.groupby('target_sid'):
    predictions_sd[sid]={category:wtvar(group,category,k) for category in categories}

# %%
loael_predictions_mean=pd.DataFrame(predictions_mean.values(),index=predictions_mean.keys())
loael_predictions_mean=loael_predictions_mean.merge(loael_agg_mean,right_index=True,left_index=True)
len(loael_predictions_mean)
loael_predictions_mean.head()
loael_predictions_mean.to_csv(DAT_DIR+'loael_predictions_mean_mrgn.csv')
# Out:
# 1004
#                cholinesterase_p  developmental_p  reproductive_p  systemic_p  \
# DTXSID4047672          3.889967         3.493957        3.282332    3.362421
# DTXSID1020485          5.304208         3.041462        3.113375    2.914006
# DTXSID3024235          4.360391         3.965492        3.873737    3.695860
# DTXSID2044343          3.922568         4.112034        3.319040    3.573338
# DTXSID7030066          5.827070         2.982922        3.068403    3.887838
#
#                cholinesterase  developmental  reproductive  systemic
# DTXSID4047672             NaN       3.836210           NaN  2.942306
# DTXSID1020485             NaN            NaN           NaN  4.135310
# DTXSID3024235             NaN       5.896800      4.255822  4.594689
# DTXSID2044343             NaN       4.026338           NaN  3.681471
# DTXSID7030066             NaN            NaN           NaN  9.230972

# %%
loael_predictions_sd=pd.DataFrame(predictions_sd.values(),index=predictions_sd.keys())
loael_predictions_sd=loael_predictions_sd.merge(loael_agg_sd,right_index=True,left_index=True)
loael_predictions_sd.to_csv(DAT_DIR+'loael_predictions_sd_mrgn.csv')

# %% [markdown]
# <h1>Cluster Analysis</h1>

# %%
con=pymongo.MongoClient("mongodb://ghelman:ghelman@pb.epa.gov/genra_v3")
DB2 = con['genra_v3']
clusters_collection=DB2['clusters1']

# %%
clusters=list(clusters_collection.find({},{'_id':0,'chems':1,'cl_id':1}))

# %%
cid_list=[chem for cluster in [cluster['chems'] for cluster in clusters] for chem in cluster]

# %%
cid_to_sid={record['dsstox_cid']:record['dsstox_sid'] for record in dsstox.find({'dsstox_cid':{'$in':cid_list}})}

# %%
for cluster in clusters:
    cluster['chems']=[cid_to_sid[cid] for cid in cluster['chems'] if cid in cid_to_sid.keys()]

# %%
import pickle as pkl
with open(DAT_DIR+'clusters.pkl','w') as f:
    pkl.dump(clusters,f)

# %% [markdown]
# <h1>k,s grid search for LOAELS using mean aggregation</h1>

# %%
predictions=[]
for k in ks:
    for s in ss: 
        for sid,group in loael_neighbors_mean.groupby('target_sid'):
                prediction={category+'_p':wtavg(group,category,k,s) for category in categories}
                prediction['dsstox_sid']=sid
                prediction['k']=k
                prediction['s']=s
                predictions.append(prediction)

# %%
prediction_df=pd.DataFrame(predictions)
prediction_df=prediction_df.merge(loael_agg,left_on='dsstox_sid',right_index=True)
prediction_df.to_csv(DAT_DIR+'toxref_ks_gridsearch_mrgn.csv')

# %%
exact_k_predictions=[]
for k in ks:
    for s in ss: 
        for sid,group in loael_neighbors_mean.groupby('target_sid'):
                prediction={category+'_p':exact_k_wtavg(group,category,k,s) for category in categories}
                prediction['dsstox_sid']=sid
                prediction['k']=k
                prediction['s']=s
                exact_k_predictions.append(prediction)

# %%
exact_k_df=pd.DataFrame(exact_k_predictions)
exact_k_df=exact_k_df.merge(loael_agg,left_on='dsstox_sid',right_index=True)
exact_k_df.to_csv(DAT_DIR+'toxref_exact_ks_gridsearch_mrgn.csv')

# %% [markdown]
# <h1>k,s grid search over clusters</h1>

# %%
#Within cluster predictions
cluster_predictions=[]
for k in ks:
    for s in ss: 
        for cluster in clusters:
            chems=cluster['chems']
            cluster_df=loael_neighbors_mean[(loael_neighbors_mean['target_sid'].isin(chems)) & loael_neighbors_mean['neighbor_sid'].isin(chems)]
            for sid,group in cluster_df.groupby('target_sid'):
                prediction={category+'_p':wtavg(group,category,k,s) for category in categories}
                prediction['dsstox_sid']=sid
                prediction['k']=k
                prediction['s']=s
                prediction['cluster']=cluster['cl_id']
                cluster_predictions.append(prediction)

# %%
cluster_prediction_df=pd.DataFrame(cluster_predictions)
cluster_prediction_df=cluster_prediction_df.merge(loael_agg_mean,left_on='dsstox_sid',right_index=True)
cluster_prediction_df.to_csv(DAT_DIR+'cluster_ks_gridsearch_mrgn.csv')

# %%
#Within cluster predictions
exactk_cluster_predictions=[]
for k in ks:
    for s in ss:
        for cluster in clusters:
            chems=cluster['chems']
            cluster_df=loael_neighbors_mean[(loael_neighbors_mean['target_sid'].isin(chems)) & loael_neighbors_mean['neighbor_sid'].isin(chems)]
            for sid,group in cluster_df.groupby('target_sid'):
                prediction={category+'_p':exact_k_wtavg(group,category,k,s) for category in categories}
                prediction['dsstox_sid']=sid
                prediction['k']=k
                prediction['s']=s
                prediction['cluster']=cluster['cl_id']
                exactk_cluster_predictions.append(prediction)

# %%
exactk_cluster_prediction_df=pd.DataFrame(exactk_cluster_predictions)
exactk_cluster_prediction_df=exactk_cluster_prediction_df.merge(loael_agg_mean,left_on='dsstox_sid',right_index=True)
exactk_cluster_prediction_df.to_csv(DAT_DIR+'exactk_cluster_ks_gridsearch_mrgn.csv')

# %%
cluster_prediction_df=pd.read_csv(DAT_DIR+'cluster_ks_gridsearch.csv')
exactk_cluster_prediction_df=pd.read_csv(DAT_DIR+'exactk_cluster_ks_gridsearch.csv')

# %%
cluster_grid_r2s={}
cluster_grid_ns={}
for cluster in clusters:
    chems=cluster['chems']
    clid=int(cluster['cl_id'])
    cluster_grid_r2s[clid]=np.empty([len(ks),len(ss)])
    cluster_grid_ns[clid]=np.empty([len(ks),len(ss)])
    for (k,s),group in cluster_prediction_df.groupby(['k','s']):
        k_index=ks.index(k)
        s_index=ss.index(round(s,2))
        df=cluster_prediction_df[(cluster_prediction_df['dsstox_sid'].isin(chems))\
                                 & (cluster_prediction_df['s']==s) & (cluster_prediction_df['k']==k)]
        df=df[['systemic','systemic_p']]
        df=plot_worthy(df)
        if df.empty:
            cluster_grid_r2s[clid][k_index,s_index]=np.nan
            cluster_grid_ns[clid][k_index,s_index]=0   
            continue
        cluster_grid_r2s[clid][k_index,s_index]=r2_score(df['systemic'],df['systemic_p'])
        cluster_grid_ns[clid][k_index,s_index]=len(df)

# %%
with pd.option_context('display.float_format',lambda x: '%.3f' % x):
    for clid,grid in cluster_grid_r2s.iteritems():
        print(clid)
        print(str(cluster_grid_ns[clid].max())+ ' predictions')
        pd.DataFrame(grid)

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
i=1
fig=plt.figure(figsize=(12,300))
for clid,cluster_grid_r2 in cluster_grid_r2s.iteritems():
    fig.suptitle('k,s grid search for up to k neighbors',fontsize=20)
    ax=fig.add_subplot(50,2,i,projection='3d')
    #ax.text2D(.5,.95,'Global',transform=ax.transAxes,fontsize=20)
    X,Y=np.meshgrid(ss,ks)
    i+=1
    ax.plot_surface(X,Y,cluster_grid_r2)
    ax.set_ylabel('Maximum number of neighbors (k)',fontsize=16)
    ax.set_xlabel('Similarity threshold (s)',fontsize=16)
    ax.set_zlabel('R2')
    ax.set_title('Cluster '+ clid )
plt.subplots_adjust()
plt.savefig(FIG_DIR+'cluster_ksgrid_uptok')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

for clid,cluster_grid_r2 in cluster_grid_r2s.iteritems():
    fig=plt.figure(figsize=(8,6))
    plt.title('k,s grid search for up to k neighbors for cluster ' + str(clid),fontsize=20)
    #ax.text2D(.5,.95,'Global',transform=ax.transAxes,fontsize=20)
    X,Y=np.meshgrid(ss,ks)
    plt.contour(X,Y,cluster_grid_r2)
    plt.ylabel('Maximum number of neighbors (k)',fontsize=16)
    plt.xlabel('Similarity threshold (s)',fontsize=16)
    #ax.set_title('Cluster '+ clid )
    plt.show()
#plt.savefig(FIG_DIR+'cluster_ksgrid_uptok')
#plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
i=1
fig=plt.figure(figsize=(12,300))
for clid,cluster_grid_r2 in exactk_cluster_grid_r2s.iteritems():
    fig.suptitle('k,s grid search for exactly k neighbors',fontsize=20)
    ax=fig.add_subplot(2,50,i,projection='3d')
    #ax.text2D(.5,.95,'Global',transform=ax.transAxes,fontsize=20)
    X,Y=np.meshgrid(ss,ks)
    i+=1
    ax.plot_surface(X,Y,cluster_grid_r2)
    ax.set_ylabel('Maximum number of neighbors (k)',fontsize=16)
    ax.set_xlabel('Similarity threshold (s)',fontsize=16)
    ax.set_zlabel('R2')
    ax.set_title('Cluster '+ clid )
plt.subplots.adjust()
plt.savefig(FIG_DIR+'cluster_ksgrid_exactk')
plt.show()

# %% [markdown]
# <h1>EPA Categories</h1>

# %%
import operator as op
op_dict={
    'GreaterThan': op.gt,
    'GreaterThanOrEqualTo': op.ge,
    'LessThan': op.lt,
    'LessThanOrEqualTo': op.le
}
prop_dict={
    'log Kow':'logp',
    'Molecular Weight':'mol_weight',
    'Molecular weight':'mol_weight',
    'Water Solubility': 'ws'
}

# %%
def convert_ppb(x): #OPERA results stored as mol/L
    ws=x['ws']
    mol_weight=x['mol_weight']
    return ws*mol_weight*10**6

# %%
import dill
with open(DAT_DIR+'../category_tests.dill') as f:
    category_tests=dill.load(f)

# %%
loael_smiles=dsstox.find({'dsstox_sid':{'$in':loael_sids}},{'_id':0,'dsstox_sid':1,'smiles':1})
smiles_dict={record['dsstox_sid']:record['smiles'] for record in loael_smiles}
loael_logp=physprop.find({'dsstox_sid':{'$in':loael_sids}},{'_id':0,'dsstox_sid':1,'predicted_props.OPERA_LogP':1})
logp_dict={record['dsstox_sid']:record.get('predicted_props',{})['OPERA_LogP'][0] for record in loael_logp \
           if 'OPERA_LogP' in record.get('predicted_props',{}) and record.get('dsstox_sid',None)}
loael_ws=physprop.find({'dsstox_sid':{'$in':loael_sids}},{'_id':0,'dsstox_sid':1,'predicted_props.OPERA_WS':1})
ws_dict={record['dsstox_sid']:record.get('predicted_props',{})['OPERA_WS'][0] for record in loael_ws \
           if 'OPERA_WS' in record.get('predicted_props',{}) and record.get('dsstox_sid',None)}
loael_weight=dsstox.find({'dsstox_sid':{'$in':loael_sids}})
weight_dict={record['dsstox_sid']:record['mol_weight'] for record in loael_weight}

# %%
from rdkit import Chem
sids=set(logp_dict.keys())&set(ws_dict.keys())&set(weight_dict.keys())
records=[]
for sid in sids:
    records.append({'dsstox_sid':sid,'smiles':smiles_dict[sid],'logp':logp_dict[sid],'ws':ws_dict[sid],'mol_weight':weight_dict[sid],'mol':Chem.MolFromSmiles(smiles_dict[sid])})
records=[record for record in records if record['mol']]

# %%
import math
for record in records:
    if not record['mol']:
        continue
    epa_categories=sorted([category for category,test in category_tests.iteritems() if test(record)])
    if 'Neutral Organics' in epa_categories and len(epa_categories)>1:
        epa_categories.remove('Neutral Organics')
    record['categories']=tuple(epa_categories)

# %%
from collections import Counter
count=Counter(record['categories'] for record in records)
count
# Out:
# Counter({(): 569,
#          ('Acrylamides',): 3,
#          ('Acrylates/Methacrylates (Acute toxicity)',
#           'Esters (Acute toxicity)'): 1,
#          ('Aldehydes (Acute toxicity)',): 6,
#          ('Alkoxysilanes', 'Cationic (quaternary ammonium) surfactants'): 1,
#          ('Anhydrides, Carboxylic acid',): 2,
#          ('Anilines (Acute toxicity)',): 26,
#          ('Anilines (Acute toxicity)', 'Dianilines'): 2,
#          ('Anilines (Acute toxicity)', 'Phenols (Acute toxicity)'): 2,
#          ('Anilines (Acute toxicity)',
#           'Polynitroaromatics (Acute toxicity)'): 1,
#          ('Anionic Surfactants',): 1,
#          ('Azides (Acute toxicity)',): 1,
#          ('Benzotriazoles (Acute toxicity)',): 1,
#          ('Cationic (quaternary ammonium) surfactants',): 9,
#          ('Diisocyanates',): 1,
#          ('Dithiocarbamates (Acute toxicity)',): 3,
#          ('Epoxides',): 8,
#          ('Esters (Acute toxicity)',): 82,
#          ('Esters (Acute toxicity)', 'Imides (Acute toxicity)'): 2,
#          ('Esters (Acute toxicity)', 'Phenols (Acute toxicity)'): 7,
#          ('Esters (Acute toxicity)',
#           'Substituted Triazines (Acute toxicity)'): 5,
#          ('Esters (Chronic toxicity)',): 24,
#          ('Ethylene Glycol Ethers',): 9,
#          ('Hydrazines and Related Compounds',): 14,
#          ('Imides (Acute toxicity)',): 9,
#          ('Neutral Organics',): 83,
#          ('Peroxides',): 1,
#          ('Phenolphthaleins', 'Phenols (Acute toxicity)'): 1,
#          ('Phenols (Acute toxicity)',): 63,
#          ('Phenols (Acute toxicity)',
#           'Polynitroaromatics (Acute toxicity)'): 3,
#          ('Polynitroaromatics (Acute toxicity)',): 9,
#          ('Substituted Triazines (Acute toxicity)',): 28,
#          ('Thiols (Acute toxicity)',): 1})

# %%
from collections import defaultdict
search_spaces=defaultdict(list)
for record in records:
    search_spaces[record['categories']].append(record['dsstox_sid'])
search_spaces={cat:l for cat,l in search_spaces.iteritems() if len(l)>1}
import pickle
with open(DAT_DIR+'search_spaces.pkl','w') as f:
    pickle.dump(search_spaces,f)

# %%
category_neighbors_l=[]
for record in records:
    sid=record['dsstox_sid']
    search_space=search_spaces[record['categories']][:]
    if len(search_space)==1:
        continue
    search_space.remove(sid)
    sid_neighbors=searchCollByFP(sid,s0=.05,SID=search_space,DB=DB)
    if sid_neighbors:
        for neighbor in sid_neighbors:
            neighbor['target_sid']=sid
            neighbor['neighbor_sid']=neighbor.pop('dsstox_sid')
        category_neighbors_l=category_neighbors_l+sid_neighbors

# %%
category_neighbors=pd.DataFrame(category_neighbors_l)
category_neighbors=category_neighbors[category_neighbors['target_sid']!=category_neighbors['neighbor_sid']]
category_neighbors=category_neighbors.merge(loael_agg_mean,left_on='neighbor_sid',right_index=True)
category_neighbors=category_neighbors.sort_values('jaccard',ascending=False)
category_neighbors.to_csv(DAT_DIR+'category_neighbors_mrgn.csv',index=False)
category_neighbors.head()
# Out:
#             casrn  jaccard             name   neighbor_sid     target_sid  \
# 52165  51630-58-1      1.0      Fenvalerate  DTXSID3020621  DTXSID4032667
# 48004    138-86-3      1.0         Limonene  DTXSID2029612  DTXSID1020778
# 38245  69806-50-4      1.0  Fluazifop-butyl  DTXSID3034612  DTXSID0034855
# 45772     60-57-1      1.0         Dieldrin  DTXSID9020453  DTXSID6020561
# 21584  28434-00-6      1.0   S-Bioallethrin  DTXSID2039336  DTXSID8035180
#
#        cholinesterase  developmental  reproductive  systemic
# 52165             NaN            NaN           NaN  4.331634
# 48004             NaN       2.435328           NaN  2.435328
# 38245             NaN       4.583615      4.340577  4.300948
# 45772             NaN            NaN      5.705760  5.581639
# 21584             NaN       3.781632      3.190567  3.518175

# %%
predictions={}
k=10
s=.05
for sid,group in category_neighbors.groupby('target_sid'):
    predictions[sid]={category+'_p':wtavg(group,category,k,s) for category in categories}

# %%
category_predictions=pd.DataFrame(predictions.values(),index=predictions.keys())
category_predictions=category_predictions.merge(loael_agg_mean,right_index=True,left_index=True)
category_predictions.to_csv(DAT_DIR+'category_predictions_mrgn.csv')
category_predictions.head()
# Out:
#                cholinesterase_p  developmental_p  reproductive_p  systemic_p  \
# DTXSID0020076          5.266096         3.412768        3.369072    3.325482
# DTXSID0020151          5.004252         2.896481        3.354341    2.573533
# DTXSID0020232          5.158729         3.556275        3.260099    3.224968
# DTXSID0020311          3.946856         3.296379        3.151303    3.521586
# DTXSID0020315          5.550991         3.466629        2.720297    3.004631
#
#                cholinesterase  developmental  reproductive  systemic
# DTXSID0020076             NaN       3.322643      2.322643  3.322643
# DTXSID0020151             NaN            NaN           NaN  2.146777
# DTXSID0020232             NaN       3.191326      3.191326  3.191326
# DTXSID0020311             NaN            NaN           NaN  2.662276
# DTXSID0020315             NaN            NaN      5.136641  5.093944
